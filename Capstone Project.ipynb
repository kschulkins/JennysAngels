# %% [markdown]
# # Capstone Project

# %% [markdown]
# Learning Objectives:
#
# - Incorporate Illinois Reboot toolchain into a single nose-to-tail project.

# %% [markdown]
# ## The Data Set

# %% [markdown]
# You work for a regional soft drink distribution center that has access to invoice data from convenience stores (`invoices.csv`), product data (`items.csv`), and customer reviews (the files in `reviews/`).
#
# You would like to examine the data for a few features, then plug them into a recommendation engine to see if you can improve sales.
#
# For instance, each data set should be validated and the fields (columns), basic data statistics, and any outliers should be reported.  Then further analysis can take place.
#
# You may use Bash, Python (likely Pandas), SQL, and Git to complete this project.  I make some suggestions at various junctures to consider using particular tools, but feel free to solve the problem in any manner your team finds fitting.  _The entire team should read the entire project and discuss before making any decisions about platform._
#
# You should produce a final report which responds to all of the **bolded** questions and includes full code and an explanation of its use.  You should not use a spreadsheet tool to complete any part of this project even if tempted—in particular, the `invoices.csv` file is too large to load in Microsoft Excel.
#
# In general, feel free to reach out to me.  Follow the outline, but make this _your_ project.

# %% [markdown]
# ### `items.csv`

# %% [markdown]
# The first data set you have available is a table of soft drink products with various data.  **Produce a brief report of the field names and associated column statistics for the table.**  Consider producing scatter plots of certain values, such as the bottle volume.
#
# Each time you load a data table, you should carefully consider which fields should be numeric and which text.  For instance, a name is clearly text while a volume is numeric.  A product ID even if all numeric should be text, though.  (Can you think of why?)

# %%
import pandas as pd
csv = pd.read_csv('data_code/item.csv')
csv.head(3)
# Out:
#    Item_id          Item_Description         Category  Pack  Bottle_Volume_ml  \
# 0      101   Kanna's Grapefruit Soda  Grapefruit Soda     6             750.0
# 1      102    Alphonse's Fruit Punch      Fruit Punch     6             800.0
# 2      103  Yummy Surstromming Juice              NaN     1             750.0
#
#    Bottle_Cost  Bottle_Retail_Price
# 0         4.32                 6.48
# 1         3.33                 5.00
# 2        10.30                20.10

# %%
print(csv.shape)
# Out:
# (4166, 7)

# %%
csv.describe()
# Out:
#              Item_id         Pack  Bottle_Volume_ml  Bottle_Cost  \
# count    4166.000000  4166.000000       4166.000000  4166.000000
# mean   154512.392943    11.260442        936.963274     3.648721
# std    292382.354448    11.913901       6244.415564     9.348512
# min       101.000000     1.000000          0.000000     1.500000
# 25%     28799.250000     6.000000        750.000000     2.360000
# 50%     43336.500000    12.000000        750.000000     2.860000
# 75%     78591.500000    12.000000        750.000000     3.610000
# max    996026.000000   336.000000     378000.000000   500.000000
#
#        Bottle_Retail_Price
# count          4163.000000
# mean              5.485763
# std              14.027764
# min               2.450000
# 25%               3.580000
# 50%               4.300000
# 75%               5.420000
# max             750.000000

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4166 entries, 0 to 4165
# Data columns (total 7 columns):
# Item_id                4166 non-null int64
# Item_Description       4166 non-null object
# Category               4162 non-null object
# Pack                   4166 non-null int64
# Bottle_Volume_ml       4166 non-null float64
# Bottle_Cost            4166 non-null float64
# Bottle_Retail_Price    4163 non-null float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 227.9+ KB

# %% [markdown]
# To do
# 1. change to proper data types
# 2. clean up/ round some numbers
# 3. determine how to deal with Category nulls and retail price nulls

# %% [markdown]
# ### `invoices.csv`

# %% [markdown]
# The invoice data set is quite large, too large in fact to be loaded by a conventional spreadsheet program.  Thus you will need to use Python or SQL to manage the data set.  You will not need to create additional fields (columns) in the table, but you will need to be able to merge data tables.
#
# As before, **produce a report containing the field names and column statistics for the table.**
#
# If using Python, Pandas should be able to readily handle the import.
#
# If using SQL, you can [import the CSV file directly](https://www.sqlite.org/cli.html#importing_csv_files).

# %%
csv = pd.read_csv('data_code/invoice.csv')
csv.head(3)
# Out:
#         Invoice_id        Date  Item_id  Vendor_id        Vendor_Name  \
# 0  INV-00013400001  2016-08-29    35918        297      Katou Company
# 1  INV-00013400002  2016-08-29    23828        297      Katou Company
# 2  INV-00013400003  2016-08-29    36908        300  Katsuragi Company
#
#    Store_id                  Store_Name            Address  City_Name  \
# 0      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 1      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 2      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
#
#    Zip_Code  County_id County_Name  Bottles_Sold
# 0     52802         82       Scott             1
# 1     52802         82       Scott             1
# 2     52802         82       Scott             1

# %%
print(csv.shape)
# Out:
# (930508, 13)

# %%
csv.describe()
# Out:
#              Item_id      Vendor_id       Store_id       Zip_Code  \
# count  930508.000000  930508.000000  930508.000000  930508.000000
# mean    46100.761759     257.759544    3475.512880   52132.305486
# std     42887.410193     137.428615     889.217119     823.575059
# min       101.000000      10.000000    2554.000000   51101.000000
# 25%     29993.000000     115.000000    2623.000000   51106.000000
# 50%     41019.000000     260.000000    3447.000000   52803.000000
# 75%     64571.000000     380.000000    4076.000000   52806.000000
# max    996026.000000     987.000000    9922.000000   52807.000000
#
#            County_id   Bottles_Sold
# count  930508.000000  930508.000000
# mean       87.817790       9.875647
# std         7.308914      22.489171
# min        82.000000       0.000000
# 25%        82.000000       2.000000
# 50%        82.000000       6.000000
# 75%        97.000000      12.000000
# max        97.000000    2160.000000

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930508 entries, 0 to 930507
# Data columns (total 13 columns):
# Invoice_id      930508 non-null object
# Date            930508 non-null object
# Item_id         930508 non-null int64
# Vendor_id       930508 non-null int64
# Vendor_Name     930508 non-null object
# Store_id        930508 non-null int64
# Store_Name      930508 non-null object
# Address         930508 non-null object
# City_Name       930508 non-null object
# Zip_Code        930508 non-null int64
# County_id       930508 non-null int64
# County_Name     930508 non-null object
# Bottles_Sold    930508 non-null int64
# dtypes: int64(6), object(7)
# memory usage: 92.3+ MB

# %% [markdown]
# ### Reviews

# %% [markdown]
# The customer reviews have been stored in separate files with the format
#
# ```
# Customer ID: 6880
# Invoice ID: INV-01352200015
# Product Rating: 2/5
# ```
#
# As there are several thousand of these reviews, you should aggregate them into a single data table for ease of use.  Bash or Python should be preferred; if working in SQL then use Python and the PySQL interface to produce the SQL database.
#
# As there are a lot of these to load, I suggest that you load only a small subset, a hundred or a thousand, first, and get things working before you load the entire data set.
#
# **Produce a short report about the aggregated review database.**

# %%
pd.read_csv('reviews/review00001.dat')
# Out:
#           Customer ID: 9192
# 0  Invoice ID: S05392500012
# 1       Product Rating: 3/5

# %%
rev = pd.read_csv('reviews/review00001.dat',names=['values'],delimiter=':')

# %%
rev
# Out:
#                        values
# Customer ID              9192
# Invoice ID       S05392500012
# Product Rating            3/5

# %%
from glob import glob
glob('reviews/review*.dat')
# Out:
# ['reviews\\review00000.dat',
#  'reviews\\review00001.dat',
#  'reviews\\review00002.dat',
#  'reviews\\review00003.dat',
#  'reviews\\review00004.dat',
#  'reviews\\review00005.dat',
#  'reviews\\review00006.dat',
#  'reviews\\review00007.dat',
#  'reviews\\review00008.dat',
#  'reviews\\review00009.dat',
#  'reviews\\review00010.dat',
#  'reviews\\review00011.dat',
#  'reviews\\review00012.dat',
#  'reviews\\review00013.dat',
#  'reviews\\review00014.dat',
#  'reviews\\review00015.dat',
#  'reviews\\review00016.dat',
#  'reviews\\review00017.dat',
#  'reviews\\review00018.dat',
#  'reviews\\review00019.dat',
#  'reviews\\review00020.dat',
#  'reviews\\review00021.dat',
#  'reviews\\review00022.dat',
#  'reviews\\review00023.dat',
#  'reviews\\review00024.dat',
#  'reviews\\review00025.dat',
#  'reviews\\review00026.dat',
#  'reviews\\review00027.dat',
#  'reviews\\review00028.dat',
#  'reviews\\review00029.dat',
#  'reviews\\review00030.dat',
#  'reviews\\review00031.dat',
#  'reviews\\review00032.dat',
#  'reviews\\review00033.dat',
#  'reviews\\review00034.dat',
#  'reviews\\review00035.dat',
#  'reviews\\review00036.dat',
#  'reviews\\review00037.dat',
#  'reviews\\review00038.dat',
#  'reviews\\review00039.dat',
#  'reviews\\review00040.dat',
#  'reviews\\review00041.dat',
#  'reviews\\review00042.dat',
#  'reviews\\review00043.dat',
#  'reviews\\review00044.dat',
#  'reviews\\review00045.dat',
#  'reviews\\review00046.dat',
#  'reviews\\review00047.dat',
#  'reviews\\review00048.dat',
#  'reviews\\review00049.dat',
#  'reviews\\review00050.dat',
#  'reviews\\review00051.dat',
#  'reviews\\review00052.dat',
#  'reviews\\review00053.dat',
#  'reviews\\review00054.dat',
#  'reviews\\review00055.dat',
#  'reviews\\review00056.dat',
#  'reviews\\review00057.dat',
#  'reviews\\review00058.dat',
#  'reviews\\review00059.dat',
#  'reviews\\review00060.dat',
#  'reviews\\review00061.dat',
#  'reviews\\review00062.dat',
#  'reviews\\review00063.dat',
#  'reviews\\review00064.dat',
#  'reviews\\review00065.dat',
#  'reviews\\review00066.dat',
#  'reviews\\review00067.dat',
#  'reviews\\review00068.dat',
#  'reviews\\review00069.dat',
#  'reviews\\review00070.dat',
#  'reviews\\review00071.dat',
#  'reviews\\review00072.dat',
#  'reviews\\review00073.dat',
#  'reviews\\review00074.dat',
#  'reviews\\review00075.dat',
#  'reviews\\review00076.dat',
#  'reviews\\review00077.dat',
#  'reviews\\review00078.dat',
#  'reviews\\review00079.dat',
#  'reviews\\review00080.dat',
#  'reviews\\review00081.dat',
#  'reviews\\review00082.dat',
#  'reviews\\review00083.dat',
#  'reviews\\review00084.dat',
#  'reviews\\review00085.dat',
#  'reviews\\review00086.dat',
#  'reviews\\review00087.dat',
#  'reviews\\review00088.dat',
#  'reviews\\review00089.dat',
#  'reviews\\review00090.dat',
#  'reviews\\review00091.dat',
#  'reviews\\review00092.dat',
#  'reviews\\review00093.dat',
#  'reviews\\review00094.dat',
#  'reviews\\review00095.dat',
#  'reviews\\review00096.dat',
#  'reviews\\review00097.dat',
#  'reviews\\review00098.dat',
#  'reviews\\review00099.dat',
#  'reviews\\review00100.dat',
#  'reviews\\review00101.dat',
#  'reviews\\review00102.dat',
#  'reviews\\review00103.dat',
#  'reviews\\review00104.dat',
#  'reviews\\review00105.dat',
#  'reviews\\review00106.dat',
#  'reviews\\review00107.dat',
#  'reviews\\review00108.dat',
#  'reviews\\review00109.dat',
#  'reviews\\review00110.dat',
#  'reviews\\review00111.dat',
#  'reviews\\review00112.dat',
#  'reviews\\review00113.dat',
#  'reviews\\review00114.dat',
#  'reviews\\review00115.dat',
#  'reviews\\review00116.dat',
#  'reviews\\review00117.dat',
#  'reviews\\review00118.dat',
#  'reviews\\review00119.dat',
#  'reviews\\review00120.dat',
#  'reviews\\review00121.dat',
#  'reviews\\review00122.dat',
#  'reviews\\review00123.dat',
#  'reviews\\review00124.dat',
#  'reviews\\review00125.dat',
#  'reviews\\review00126.dat',
#  'reviews\\review00127.dat',
#  'reviews\\review00128.dat',
#  'reviews\\review00129.dat',
#  'reviews\\review00130.dat',
#  'reviews\\review00131.dat',
#  'reviews\\review00132.dat',
#  'reviews\\review00133.dat',
#  'reviews\\review00134.dat',
#  'reviews\\review00135.dat',
#  'reviews\\review00136.dat',
#  'reviews\\review00137.dat',
#  'reviews\\review00138.dat',
#  'reviews\\review00139.dat',
#  'reviews\\review00140.dat',
#  'reviews\\review00141.dat',
#  'reviews\\review00142.dat',
#  'reviews\\review00143.dat',
#  'reviews\\review00144.dat',
#  'reviews\\review00145.dat',
#  'reviews\\review00146.dat',
#  'reviews\\review00147.dat',
#  'reviews\\review00148.dat',
#  'reviews\\review00149.dat',
#  'reviews\\review00150.dat',
#  'reviews\\review00151.dat',
#  'reviews\\review00152.dat',
#  'reviews\\review00153.dat',
#  'reviews\\review00154.dat',
#  'reviews\\review00155.dat',
#  'reviews\\review00156.dat',
#  'reviews\\review00157.dat',
#  'reviews\\review00158.dat',
#  'reviews\\review00159.dat',
#  'reviews\\review00160.dat',
#  'reviews\\review00161.dat',
#  'reviews\\review00162.dat',
#  'reviews\\review00163.dat',
#  'reviews\\review00164.dat',
#  'reviews\\review00165.dat',
#  'reviews\\review00166.dat',
#  'reviews\\review00167.dat',
#  'reviews\\review00168.dat',
#  'reviews\\review00169.dat',
#  'reviews\\review00170.dat',
#  'reviews\\review00171.dat',
#  'reviews\\review00172.dat',
#  'reviews\\review00173.dat',
#  'reviews\\review00174.dat',
#  'reviews\\review00175.dat',
#  'reviews\\review00176.dat',
#  'reviews\\review00177.dat',
#  'reviews\\review00178.dat',
#  'reviews\\review00179.dat',
#  'reviews\\review00180.dat',
#  'reviews\\review00181.dat',
#  'reviews\\review00182.dat',
#  'reviews\\review00183.dat',
#  'reviews\\review00184.dat',
#  'reviews\\review00185.dat',
#  'reviews\\review00186.dat',
#  'reviews\\review00187.dat',
#  'reviews\\review00188.dat',
#  'reviews\\review00189.dat',
#  'reviews\\review00190.dat',
#  'reviews\\review00191.dat',
#  'reviews\\review00192.dat',
#  'reviews\\review00193.dat',
#  'reviews\\review00194.dat',
#  'reviews\\review00195.dat',
#  'reviews\\review00196.dat',
#  'reviews\\review00197.dat',
#  'reviews\\review00198.dat',
#  'reviews\\review00199.dat',
#  'reviews\\review00200.dat',
#  'reviews\\review00201.dat',
#  'reviews\\review00202.dat',
#  'reviews\\review00203.dat',
#  'reviews\\review00204.dat',
#  'reviews\\review00205.dat',
#  'reviews\\review00206.dat',
#  'reviews\\review00207.dat',
#  'reviews\\review00208.dat',
#  'reviews\\review00209.dat',
#  'reviews\\review00210.dat',
#  'reviews\\review00211.dat',
#  'reviews\\review00212.dat',
#  'reviews\\review00213.dat',
#  'reviews\\review00214.dat',
#  'reviews\\review00215.dat',
#  'reviews\\review00216.dat',
#  'reviews\\review00217.dat',
#  'reviews\\review00218.dat',
#  'reviews\\review00219.dat',
#  'reviews\\review00220.dat',
#  'reviews\\review00221.dat',
#  'reviews\\review00222.dat',
#  'reviews\\review00223.dat',
#  'reviews\\review00224.dat',
#  'reviews\\review00225.dat',
#  'reviews\\review00226.dat',
#  'reviews\\review00227.dat',
#  'reviews\\review00228.dat',
#  'reviews\\review00229.dat',
#  'reviews\\review00230.dat',
#  'reviews\\review00231.dat',
#  'reviews\\review00232.dat',
#  'reviews\\review00233.dat',
#  'reviews\\review00234.dat',
#  'reviews\\review00235.dat',
#  'reviews\\review00236.dat',
#  'reviews\\review00237.dat',
#  'reviews\\review00238.dat',
#  'reviews\\review00239.dat',
#  'reviews\\review00240.dat',
#  'reviews\\review00241.dat',
#  'reviews\\review00242.dat',
#  'reviews\\review00243.dat',
#  'reviews\\review00244.dat',
#  'reviews\\review00245.dat',
#  'reviews\\review00246.dat',
#  'reviews\\review00247.dat',
#  'reviews\\review00248.dat',
#  'reviews\\review00249.dat',
#  'reviews\\review00250.dat',
#  'reviews\\review00251.dat',
#  'reviews\\review00252.dat',
#  'reviews\\review00253.dat',
#  'reviews\\review00254.dat',
#  'reviews\\review00255.dat',
#  'reviews\\review00256.dat',
#  'reviews\\review00257.dat',
#  'reviews\\review00258.dat',
#  'reviews\\review00259.dat',
#  'reviews\\review00260.dat',
#  'reviews\\review00261.dat',
#  'reviews\\review00262.dat',
#  'reviews\\review00263.dat',
#  'reviews\\review00264.dat',
#  'reviews\\review00265.dat',
#  'reviews\\review00266.dat',
#  'reviews\\review00267.dat',
#  'reviews\\review00268.dat',
#  'reviews\\review00269.dat',
#  'reviews\\review00270.dat',
#  'reviews\\review00271.dat',
#  'reviews\\review00272.dat',
#  'reviews\\review00273.dat',
#  'reviews\\review00274.dat',
#  'reviews\\review00275.dat',
#  'reviews\\review00276.dat',
#  'reviews\\review00277.dat',
#  'reviews\\review00278.dat',
#  'reviews\\review00279.dat',
#  'reviews\\review00280.dat',
#  'reviews\\review00281.dat',
#  'reviews\\review00282.dat',
#  'reviews\\review00283.dat',
#  'reviews\\review00284.dat',
#  'reviews\\review00285.dat',
#  'reviews\\review00286.dat',
#  'reviews\\review00287.dat',
#  'reviews\\review00288.dat',
#  'reviews\\review00289.dat',
#  'reviews\\review00290.dat',
#  'reviews\\review00291.dat',
#  'reviews\\review00292.dat',
#  'reviews\\review00293.dat',
#  'reviews\\review00294.dat',
#  'reviews\\review00295.dat',
#  'reviews\\review00296.dat',
#  'reviews\\review00297.dat',
#  'reviews\\review00298.dat',
#  'reviews\\review00299.dat',
#  'reviews\\review00300.dat',
#  'reviews\\review00301.dat',
#  'reviews\\review00302.dat',
#  'reviews\\review00303.dat',
#  'reviews\\review00304.dat',
#  'reviews\\review00305.dat',
#  'reviews\\review00306.dat',
#  'reviews\\review00307.dat',
#  'reviews\\review00308.dat',
#  'reviews\\review00309.dat',
#  'reviews\\review00310.dat',
#  'reviews\\review00311.dat',
#  'reviews\\review00312.dat',
#  'reviews\\review00313.dat',
#  'reviews\\review00314.dat',
#  'reviews\\review00315.dat',
#  'reviews\\review00316.dat',
#  'reviews\\review00317.dat',
#  'reviews\\review00318.dat',
#  'reviews\\review00319.dat',
#  'reviews\\review00320.dat',
#  'reviews\\review00321.dat',
#  'reviews\\review00322.dat',
#  'reviews\\review00323.dat',
#  'reviews\\review00324.dat',
#  'reviews\\review00325.dat',
#  'reviews\\review00326.dat',
#  'reviews\\review00327.dat',
#  'reviews\\review00328.dat',
#  'reviews\\review00329.dat',
#  'reviews\\review00330.dat',
#  'reviews\\review00331.dat',
#  'reviews\\review00332.dat',
#  'reviews\\review00333.dat',
#  'reviews\\review00334.dat',
#  'reviews\\review00335.dat',
#  'reviews\\review00336.dat',
#  'reviews\\review00337.dat',
#  'reviews\\review00338.dat',
#  'reviews\\review00339.dat',
#  'reviews\\review00340.dat',
#  'reviews\\review00341.dat',
#  'reviews\\review00342.dat',
#  'reviews\\review00343.dat',
#  'reviews\\review00344.dat',
#  'reviews\\review00345.dat',
#  'reviews\\review00346.dat',
#  'reviews\\review00347.dat',
#  'reviews\\review00348.dat',
#  'reviews\\review00349.dat',
#  'reviews\\review00350.dat',
#  'reviews\\review00351.dat',
#  'reviews\\review00352.dat',
#  'reviews\\review00353.dat',
#  'reviews\\review00354.dat',
#  'reviews\\review00355.dat',
#  'reviews\\review00356.dat',
#  'reviews\\review00357.dat',
#  'reviews\\review00358.dat',
#  'reviews\\review00359.dat',
#  'reviews\\review00360.dat',
#  'reviews\\review00361.dat',
#  'reviews\\review00362.dat',
#  'reviews\\review00363.dat',
#  'reviews\\review00364.dat',
#  'reviews\\review00365.dat',
#  'reviews\\review00366.dat',
#  'reviews\\review00367.dat',
#  'reviews\\review00368.dat',
#  'reviews\\review00369.dat',
#  'reviews\\review00370.dat',
#  'reviews\\review00371.dat',
#  'reviews\\review00372.dat',
#  'reviews\\review00373.dat',
#  'reviews\\review00374.dat',
#  'reviews\\review00375.dat',
#  'reviews\\review00376.dat',
#  'reviews\\review00377.dat',
#  'reviews\\review00378.dat',
#  'reviews\\review00379.dat',
#  'reviews\\review00380.dat',
#  'reviews\\review00381.dat',
#  'reviews\\review00382.dat',
#  'reviews\\review00383.dat',
#  'reviews\\review00384.dat',
#  'reviews\\review00385.dat',
#  'reviews\\review00386.dat',
#  'reviews\\review00387.dat',
#  'reviews\\review00388.dat',
#  'reviews\\review00389.dat',
#  'reviews\\review00390.dat',
#  'reviews\\review00391.dat',
#  'reviews\\review00392.dat',
#  'reviews\\review00393.dat',
#  'reviews\\review00394.dat',
#  'reviews\\review00395.dat',
#  'reviews\\review00396.dat',
#  'reviews\\review00397.dat',
#  'reviews\\review00398.dat',
#  'reviews\\review00399.dat',
#  'reviews\\review00400.dat',
#  'reviews\\review00401.dat',
#  'reviews\\review00402.dat',
#  'reviews\\review00403.dat',
#  'reviews\\review00404.dat',
#  'reviews\\review00405.dat',
#  'reviews\\review00406.dat',
#  'reviews\\review00407.dat',
#  'reviews\\review00408.dat',
#  'reviews\\review00409.dat',
#  'reviews\\review00410.dat',
#  'reviews\\review00411.dat',
#  'reviews\\review00412.dat',
#  'reviews\\review00413.dat',
#  'reviews\\review00414.dat',
#  'reviews\\review00415.dat',
#  'reviews\\review00416.dat',
#  'reviews\\review00417.dat',
#  'reviews\\review00418.dat',
#  'reviews\\review00419.dat',
#  'reviews\\review00420.dat',
#  'reviews\\review00421.dat',
#  'reviews\\review00422.dat',
#  'reviews\\review00423.dat',
#  'reviews\\review00424.dat',
#  'reviews\\review00425.dat',
#  'reviews\\review00426.dat',
#  'reviews\\review00427.dat',
#  'reviews\\review00428.dat',
#  'reviews\\review00429.dat',
#  'reviews\\review00430.dat',
#  'reviews\\review00431.dat',
#  'reviews\\review00432.dat',
#  'reviews\\review00433.dat',
#  'reviews\\review00434.dat',
#  'reviews\\review00435.dat',
#  'reviews\\review00436.dat',
#  'reviews\\review00437.dat',
#  'reviews\\review00438.dat',
#  'reviews\\review00439.dat',
#  'reviews\\review00440.dat',
#  'reviews\\review00441.dat',
#  'reviews\\review00442.dat',
#  'reviews\\review00443.dat',
#  'reviews\\review00444.dat',
#  'reviews\\review00445.dat',
#  'reviews\\review00446.dat',
#  'reviews\\review00447.dat',
#  'reviews\\review00448.dat',
#  'reviews\\review00449.dat',
#  'reviews\\review00450.dat',
#  'reviews\\review00451.dat',
#  'reviews\\review00452.dat',
#  'reviews\\review00453.dat',
#  'reviews\\review00454.dat',
#  'reviews\\review00455.dat',
#  'reviews\\review00456.dat',
#  'reviews\\review00457.dat',
#  'reviews\\review00458.dat',
#  'reviews\\review00459.dat',
#  'reviews\\review00460.dat',
#  'reviews\\review00461.dat',
#  'reviews\\review00462.dat',
#  'reviews\\review00463.dat',
#  'reviews\\review00464.dat',
#  'reviews\\review00465.dat',
#  'reviews\\review00466.dat',
#  'reviews\\review00467.dat',
#  'reviews\\review00468.dat',
#  'reviews\\review00469.dat',
#  'reviews\\review00470.dat',
#  'reviews\\review00471.dat',
#  'reviews\\review00472.dat',
#  'reviews\\review00473.dat',
#  'reviews\\review00474.dat',
#  'reviews\\review00475.dat',
#  'reviews\\review00476.dat',
#  'reviews\\review00477.dat',
#  'reviews\\review00478.dat',
#  'reviews\\review00479.dat',
#  'reviews\\review00480.dat',
#  'reviews\\review00481.dat',
#  'reviews\\review00482.dat',
#  'reviews\\review00483.dat',
#  'reviews\\review00484.dat',
#  'reviews\\review00485.dat',
#  'reviews\\review00486.dat',
#  'reviews\\review00487.dat',
#  'reviews\\review00488.dat',
#  'reviews\\review00489.dat',
#  'reviews\\review00490.dat',
#  'reviews\\review00491.dat',
#  'reviews\\review00492.dat',
#  'reviews\\review00493.dat',
#  'reviews\\review00494.dat',
#  'reviews\\review00495.dat',
#  'reviews\\review00496.dat',
#  'reviews\\review00497.dat',
#  'reviews\\review00498.dat',
#  'reviews\\review00499.dat',
#  'reviews\\review00500.dat',
#  'reviews\\review00501.dat',
#  'reviews\\review00502.dat',
#  'reviews\\review00503.dat',
#  'reviews\\review00504.dat',
#  'reviews\\review00505.dat',
#  'reviews\\review00506.dat',
#  'reviews\\review00507.dat',
#  'reviews\\review00508.dat',
#  'reviews\\review00509.dat',
#  'reviews\\review00510.dat',
#  'reviews\\review00511.dat',
#  'reviews\\review00512.dat',
#  'reviews\\review00513.dat',
#  'reviews\\review00514.dat',
#  'reviews\\review00515.dat',
#  'reviews\\review00516.dat',
#  'reviews\\review00517.dat',
#  'reviews\\review00518.dat',
#  'reviews\\review00519.dat',
#  'reviews\\review00520.dat',
#  'reviews\\review00521.dat',
#  'reviews\\review00522.dat',
#  'reviews\\review00523.dat',
#  'reviews\\review00524.dat',
#  'reviews\\review00525.dat',
#  'reviews\\review00526.dat',
#  'reviews\\review00527.dat',
#  'reviews\\review00528.dat',
#  'reviews\\review00529.dat',
#  'reviews\\review00530.dat',
#  'reviews\\review00531.dat',
#  'reviews\\review00532.dat',
#  'reviews\\review00533.dat',
#  'reviews\\review00534.dat',
#  'reviews\\review00535.dat',
#  'reviews\\review00536.dat',
#  'reviews\\review00537.dat',
#  'reviews\\review00538.dat',
#  'reviews\\review00539.dat',
#  'reviews\\review00540.dat',
#  'reviews\\review00541.dat',
#  'reviews\\review00542.dat',
#  'reviews\\review00543.dat',
#  'reviews\\review00544.dat',
#  'reviews\\review00545.dat',
#  'reviews\\review00546.dat',
#  'reviews\\review00547.dat',
#  'reviews\\review00548.dat',
#  'reviews\\review00549.dat',
#  'reviews\\review00550.dat',
#  'reviews\\review00551.dat',
#  'reviews\\review00552.dat',
#  'reviews\\review00553.dat',
#  'reviews\\review00554.dat',
#  'reviews\\review00555.dat',
#  'reviews\\review00556.dat',
#  'reviews\\review00557.dat',
#  'reviews\\review00558.dat',
#  'reviews\\review00559.dat',
#  'reviews\\review00560.dat',
#  'reviews\\review00561.dat',
#  'reviews\\review00562.dat',
#  'reviews\\review00563.dat',
#  'reviews\\review00564.dat',
#  'reviews\\review00565.dat',
#  'reviews\\review00566.dat',
#  'reviews\\review00567.dat',
#  'reviews\\review00568.dat',
#  'reviews\\review00569.dat',
#  'reviews\\review00570.dat',
#  'reviews\\review00571.dat',
#  'reviews\\review00572.dat',
#  'reviews\\review00573.dat',
#  'reviews\\review00574.dat',
#  'reviews\\review00575.dat',
#  'reviews\\review00576.dat',
#  'reviews\\review00577.dat',
#  'reviews\\review00578.dat',
#  'reviews\\review00579.dat',
#  'reviews\\review00580.dat',
#  'reviews\\review00581.dat',
#  'reviews\\review00582.dat',
#  'reviews\\review00583.dat',
#  'reviews\\review00584.dat',
#  'reviews\\review00585.dat',
#  'reviews\\review00586.dat',
#  'reviews\\review00587.dat',
#  'reviews\\review00588.dat',
#  'reviews\\review00589.dat',
#  'reviews\\review00590.dat',
#  'reviews\\review00591.dat',
#  'reviews\\review00592.dat',
#  'reviews\\review00593.dat',
#  'reviews\\review00594.dat',
#  'reviews\\review00595.dat',
#  'reviews\\review00596.dat',
#  'reviews\\review00597.dat',
#  'reviews\\review00598.dat',
#  'reviews\\review00599.dat',
#  'reviews\\review00600.dat',
#  'reviews\\review00601.dat',
#  'reviews\\review00602.dat',
#  'reviews\\review00603.dat',
#  'reviews\\review00604.dat',
#  'reviews\\review00605.dat',
#  'reviews\\review00606.dat',
#  'reviews\\review00607.dat',
#  'reviews\\review00608.dat',
#  'reviews\\review00609.dat',
#  'reviews\\review00610.dat',
#  'reviews\\review00611.dat',
#  'reviews\\review00612.dat',
#  'reviews\\review00613.dat',
#  'reviews\\review00614.dat',
#  'reviews\\review00615.dat',
#  'reviews\\review00616.dat',
#  'reviews\\review00617.dat',
#  'reviews\\review00618.dat',
#  'reviews\\review00619.dat',
#  'reviews\\review00620.dat',
#  'reviews\\review00621.dat',
#  'reviews\\review00622.dat',
#  'reviews\\review00623.dat',
#  'reviews\\review00624.dat',
#  'reviews\\review00625.dat',
#  'reviews\\review00626.dat',
#  'reviews\\review00627.dat',
#  'reviews\\review00628.dat',
#  'reviews\\review00629.dat',
#  'reviews\\review00630.dat',
#  'reviews\\review00631.dat',
#  'reviews\\review00632.dat',
#  'reviews\\review00633.dat',
#  'reviews\\review00634.dat',
#  'reviews\\review00635.dat',
#  'reviews\\review00636.dat',
#  'reviews\\review00637.dat',
#  'reviews\\review00638.dat',
#  'reviews\\review00639.dat',
#  'reviews\\review00640.dat',
#  'reviews\\review00641.dat',
#  'reviews\\review00642.dat',
#  'reviews\\review00643.dat',
#  'reviews\\review00644.dat',
#  'reviews\\review00645.dat',
#  'reviews\\review00646.dat',
#  'reviews\\review00647.dat',
#  'reviews\\review00648.dat',
#  'reviews\\review00649.dat',
#  'reviews\\review00650.dat',
#  'reviews\\review00651.dat',
#  'reviews\\review00652.dat',
#  'reviews\\review00653.dat',
#  'reviews\\review00654.dat',
#  'reviews\\review00655.dat',
#  'reviews\\review00656.dat',
#  'reviews\\review00657.dat',
#  'reviews\\review00658.dat',
#  'reviews\\review00659.dat',
#  'reviews\\review00660.dat',
#  'reviews\\review00661.dat',
#  'reviews\\review00662.dat',
#  'reviews\\review00663.dat',
#  'reviews\\review00664.dat',
#  'reviews\\review00665.dat',
#  'reviews\\review00666.dat',
#  'reviews\\review00667.dat',
#  'reviews\\review00668.dat',
#  'reviews\\review00669.dat',
#  'reviews\\review00670.dat',
#  'reviews\\review00671.dat',
#  'reviews\\review00672.dat',
#  'reviews\\review00673.dat',
#  'reviews\\review00674.dat',
#  'reviews\\review00675.dat',
#  'reviews\\review00676.dat',
#  'reviews\\review00677.dat',
#  'reviews\\review00678.dat',
#  'reviews\\review00679.dat',
#  'reviews\\review00680.dat',
#  'reviews\\review00681.dat',
#  'reviews\\review00682.dat',
#  'reviews\\review00683.dat',
#  'reviews\\review00684.dat',
#  'reviews\\review00685.dat',
#  'reviews\\review00686.dat',
#  'reviews\\review00687.dat',
#  'reviews\\review00688.dat',
#  'reviews\\review00689.dat',
#  'reviews\\review00690.dat',
#  'reviews\\review00691.dat',
#  'reviews\\review00692.dat',
#  'reviews\\review00693.dat',
#  'reviews\\review00694.dat',
#  'reviews\\review00695.dat',
#  'reviews\\review00696.dat',
#  'reviews\\review00697.dat',
#  'reviews\\review00698.dat',
#  'reviews\\review00699.dat',
#  'reviews\\review00700.dat',
#  'reviews\\review00701.dat',
#  'reviews\\review00702.dat',
#  'reviews\\review00703.dat',
#  'reviews\\review00704.dat',
#  'reviews\\review00705.dat',
#  'reviews\\review00706.dat',
#  'reviews\\review00707.dat',
#  'reviews\\review00708.dat',
#  'reviews\\review00709.dat',
#  'reviews\\review00710.dat',
#  'reviews\\review00711.dat',
#  'reviews\\review00712.dat',
#  'reviews\\review00713.dat',
#  'reviews\\review00714.dat',
#  'reviews\\review00715.dat',
#  'reviews\\review00716.dat',
#  'reviews\\review00717.dat',
#  'reviews\\review00718.dat',
#  'reviews\\review00719.dat',
#  'reviews\\review00720.dat',
#  'reviews\\review00721.dat',
#  'reviews\\review00722.dat',
#  'reviews\\review00723.dat',
#  'reviews\\review00724.dat',
#  'reviews\\review00725.dat',
#  'reviews\\review00726.dat',
#  'reviews\\review00727.dat',
#  'reviews\\review00728.dat',
#  'reviews\\review00729.dat',
#  'reviews\\review00730.dat',
#  'reviews\\review00731.dat',
#  'reviews\\review00732.dat',
#  'reviews\\review00733.dat',
#  'reviews\\review00734.dat',
#  'reviews\\review00735.dat',
#  'reviews\\review00736.dat',
#  'reviews\\review00737.dat',
#  'reviews\\review00738.dat',
#  'reviews\\review00739.dat',
#  'reviews\\review00740.dat',
#  'reviews\\review00741.dat',
#  'reviews\\review00742.dat',
#  'reviews\\review00743.dat',
#  'reviews\\review00744.dat',
#  'reviews\\review00745.dat',
#  'reviews\\review00746.dat',
#  'reviews\\review00747.dat',
#  'reviews\\review00748.dat',
#  'reviews\\review00749.dat',
#  'reviews\\review00750.dat',
#  'reviews\\review00751.dat',
#  'reviews\\review00752.dat',
#  'reviews\\review00753.dat',
#  'reviews\\review00754.dat',
#  'reviews\\review00755.dat',
#  'reviews\\review00756.dat',
#  'reviews\\review00757.dat',
#  'reviews\\review00758.dat',
#  'reviews\\review00759.dat',
#  'reviews\\review00760.dat',
#  'reviews\\review00761.dat',
#  'reviews\\review00762.dat',
#  'reviews\\review00763.dat',
#  'reviews\\review00764.dat',
#  'reviews\\review00765.dat',
#  'reviews\\review00766.dat',
#  'reviews\\review00767.dat',
#  'reviews\\review00768.dat',
#  'reviews\\review00769.dat',
#  'reviews\\review00770.dat',
#  'reviews\\review00771.dat',
#  'reviews\\review00772.dat',
#  'reviews\\review00773.dat',
#  'reviews\\review00774.dat',
#  'reviews\\review00775.dat',
#  'reviews\\review00776.dat',
#  'reviews\\review00777.dat',
#  'reviews\\review00778.dat',
#  'reviews\\review00779.dat',
#  'reviews\\review00780.dat',
#  'reviews\\review00781.dat',
#  'reviews\\review00782.dat',
#  'reviews\\review00783.dat',
#  'reviews\\review00784.dat',
#  'reviews\\review00785.dat',
#  'reviews\\review00786.dat',
#  'reviews\\review00787.dat',
#  'reviews\\review00788.dat',
#  'reviews\\review00789.dat',
#  'reviews\\review00790.dat',
#  'reviews\\review00791.dat',
#  'reviews\\review00792.dat',
#  'reviews\\review00793.dat',
#  'reviews\\review00794.dat',
#  'reviews\\review00795.dat',
#  'reviews\\review00796.dat',
#  'reviews\\review00797.dat',
#  'reviews\\review00798.dat',
#  'reviews\\review00799.dat',
#  'reviews\\review00800.dat',
#  'reviews\\review00801.dat',
#  'reviews\\review00802.dat',
#  'reviews\\review00803.dat',
#  'reviews\\review00804.dat',
#  'reviews\\review00805.dat',
#  'reviews\\review00806.dat',
#  'reviews\\review00807.dat',
#  'reviews\\review00808.dat',
#  'reviews\\review00809.dat',
#  'reviews\\review00810.dat',
#  'reviews\\review00811.dat',
#  'reviews\\review00812.dat',
#  'reviews\\review00813.dat',
#  'reviews\\review00814.dat',
#  'reviews\\review00815.dat',
#  'reviews\\review00816.dat',
#  'reviews\\review00817.dat',
#  'reviews\\review00818.dat',
#  'reviews\\review00819.dat',
#  'reviews\\review00820.dat',
#  'reviews\\review00821.dat',
#  'reviews\\review00822.dat',
#  'reviews\\review00823.dat',
#  'reviews\\review00824.dat',
#  'reviews\\review00825.dat',
#  'reviews\\review00826.dat',
#  'reviews\\review00827.dat',
#  'reviews\\review00828.dat',
#  'reviews\\review00829.dat',
#  'reviews\\review00830.dat',
#  'reviews\\review00831.dat',
#  'reviews\\review00832.dat',
#  'reviews\\review00833.dat',
#  'reviews\\review00834.dat',
#  'reviews\\review00835.dat',
#  'reviews\\review00836.dat',
#  'reviews\\review00837.dat',
#  'reviews\\review00838.dat',
#  'reviews\\review00839.dat',
#  'reviews\\review00840.dat',
#  'reviews\\review00841.dat',
#  'reviews\\review00842.dat',
#  'reviews\\review00843.dat',
#  'reviews\\review00844.dat',
#  'reviews\\review00845.dat',
#  'reviews\\review00846.dat',
#  'reviews\\review00847.dat',
#  'reviews\\review00848.dat',
#  'reviews\\review00849.dat',
#  'reviews\\review00850.dat',
#  'reviews\\review00851.dat',
#  'reviews\\review00852.dat',
#  'reviews\\review00853.dat',
#  'reviews\\review00854.dat',
#  'reviews\\review00855.dat',
#  'reviews\\review00856.dat',
#  'reviews\\review00857.dat',
#  'reviews\\review00858.dat',
#  'reviews\\review00859.dat',
#  'reviews\\review00860.dat',
#  'reviews\\review00861.dat',
#  'reviews\\review00862.dat',
#  'reviews\\review00863.dat',
#  'reviews\\review00864.dat',
#  'reviews\\review00865.dat',
#  'reviews\\review00866.dat',
#  'reviews\\review00867.dat',
#  'reviews\\review00868.dat',
#  'reviews\\review00869.dat',
#  'reviews\\review00870.dat',
#  'reviews\\review00871.dat',
#  'reviews\\review00872.dat',
#  'reviews\\review00873.dat',
#  'reviews\\review00874.dat',
#  'reviews\\review00875.dat',
#  'reviews\\review00876.dat',
#  'reviews\\review00877.dat',
#  'reviews\\review00878.dat',
#  'reviews\\review00879.dat',
#  'reviews\\review00880.dat',
#  'reviews\\review00881.dat',
#  'reviews\\review00882.dat',
#  'reviews\\review00883.dat',
#  'reviews\\review00884.dat',
#  'reviews\\review00885.dat',
#  'reviews\\review00886.dat',
#  'reviews\\review00887.dat',
#  'reviews\\review00888.dat',
#  'reviews\\review00889.dat',
#  'reviews\\review00890.dat',
#  'reviews\\review00891.dat',
#  'reviews\\review00892.dat',
#  'reviews\\review00893.dat',
#  'reviews\\review00894.dat',
#  'reviews\\review00895.dat',
#  'reviews\\review00896.dat',
#  'reviews\\review00897.dat',
#  'reviews\\review00898.dat',
#  'reviews\\review00899.dat',
#  'reviews\\review00900.dat',
#  'reviews\\review00901.dat',
#  'reviews\\review00902.dat',
#  'reviews\\review00903.dat',
#  'reviews\\review00904.dat',
#  'reviews\\review00905.dat',
#  'reviews\\review00906.dat',
#  'reviews\\review00907.dat',
#  'reviews\\review00908.dat',
#  'reviews\\review00909.dat',
#  'reviews\\review00910.dat',
#  'reviews\\review00911.dat',
#  'reviews\\review00912.dat',
#  'reviews\\review00913.dat',
#  'reviews\\review00914.dat',
#  'reviews\\review00915.dat',
#  'reviews\\review00916.dat',
#  'reviews\\review00917.dat',
#  'reviews\\review00918.dat',
#  'reviews\\review00919.dat',
#  'reviews\\review00920.dat',
#  'reviews\\review00921.dat',
#  'reviews\\review00922.dat',
#  'reviews\\review00923.dat',
#  'reviews\\review00924.dat',
#  'reviews\\review00925.dat',
#  'reviews\\review00926.dat',
#  'reviews\\review00927.dat',
#  'reviews\\review00928.dat',
#  'reviews\\review00929.dat',
#  'reviews\\review00930.dat',
#  'reviews\\review00931.dat',
#  'reviews\\review00932.dat',
#  'reviews\\review00933.dat',
#  'reviews\\review00934.dat',
#  'reviews\\review00935.dat',
#  'reviews\\review00936.dat',
#  'reviews\\review00937.dat',
#  'reviews\\review00938.dat',
#  'reviews\\review00939.dat',
#  'reviews\\review00940.dat',
#  'reviews\\review00941.dat',
#  'reviews\\review00942.dat',
#  'reviews\\review00943.dat',
#  'reviews\\review00944.dat',
#  'reviews\\review00945.dat',
#  'reviews\\review00946.dat',
#  'reviews\\review00947.dat',
#  'reviews\\review00948.dat',
#  'reviews\\review00949.dat',
#  'reviews\\review00950.dat',
#  'reviews\\review00951.dat',
#  'reviews\\review00952.dat',
#  'reviews\\review00953.dat',
#  'reviews\\review00954.dat',
#  'reviews\\review00955.dat',
#  'reviews\\review00956.dat',
#  'reviews\\review00957.dat',
#  'reviews\\review00958.dat',
#  'reviews\\review00959.dat',
#  'reviews\\review00960.dat',
#  'reviews\\review00961.dat',
#  'reviews\\review00962.dat',
#  'reviews\\review00963.dat',
#  'reviews\\review00964.dat',
#  'reviews\\review00965.dat',
#  'reviews\\review00966.dat',
#  'reviews\\review00967.dat',
#  'reviews\\review00968.dat',
#  'reviews\\review00969.dat',
#  'reviews\\review00970.dat',
#  'reviews\\review00971.dat',
#  'reviews\\review00972.dat',
#  'reviews\\review00973.dat',
#  'reviews\\review00974.dat',
#  'reviews\\review00975.dat',
#  'reviews\\review00976.dat',
#  'reviews\\review00977.dat',
#  'reviews\\review00978.dat',
#  'reviews\\review00979.dat',
#  'reviews\\review00980.dat',
#  'reviews\\review00981.dat',
#  'reviews\\review00982.dat',
#  'reviews\\review00983.dat',
#  'reviews\\review00984.dat',
#  'reviews\\review00985.dat',
#  'reviews\\review00986.dat',
#  'reviews\\review00987.dat',
#  'reviews\\review00988.dat',
#  'reviews\\review00989.dat',
#  'reviews\\review00990.dat',
#  'reviews\\review00991.dat',
#  'reviews\\review00992.dat',
#  'reviews\\review00993.dat',
#  'reviews\\review00994.dat',
#  'reviews\\review00995.dat',
#  'reviews\\review00996.dat',
#  'reviews\\review00997.dat',
#  'reviews\\review00998.dat',
#  'reviews\\review00999.dat',
#  ...]

# %%
list_of_files = []
for i in range (0,50000):
    list_of_files.append('reviews/review' + str(i).zfill(5)+ '.dat')

# %%
list_of_files
# Out:
# ['reviews/review00000.dat',
#  'reviews/review00001.dat',
#  'reviews/review00002.dat',
#  'reviews/review00003.dat',
#  'reviews/review00004.dat',
#  'reviews/review00005.dat',
#  'reviews/review00006.dat',
#  'reviews/review00007.dat',
#  'reviews/review00008.dat',
#  'reviews/review00009.dat',
#  'reviews/review00010.dat',
#  'reviews/review00011.dat',
#  'reviews/review00012.dat',
#  'reviews/review00013.dat',
#  'reviews/review00014.dat',
#  'reviews/review00015.dat',
#  'reviews/review00016.dat',
#  'reviews/review00017.dat',
#  'reviews/review00018.dat',
#  'reviews/review00019.dat',
#  'reviews/review00020.dat',
#  'reviews/review00021.dat',
#  'reviews/review00022.dat',
#  'reviews/review00023.dat',
#  'reviews/review00024.dat',
#  'reviews/review00025.dat',
#  'reviews/review00026.dat',
#  'reviews/review00027.dat',
#  'reviews/review00028.dat',
#  'reviews/review00029.dat',
#  'reviews/review00030.dat',
#  'reviews/review00031.dat',
#  'reviews/review00032.dat',
#  'reviews/review00033.dat',
#  'reviews/review00034.dat',
#  'reviews/review00035.dat',
#  'reviews/review00036.dat',
#  'reviews/review00037.dat',
#  'reviews/review00038.dat',
#  'reviews/review00039.dat',
#  'reviews/review00040.dat',
#  'reviews/review00041.dat',
#  'reviews/review00042.dat',
#  'reviews/review00043.dat',
#  'reviews/review00044.dat',
#  'reviews/review00045.dat',
#  'reviews/review00046.dat',
#  'reviews/review00047.dat',
#  'reviews/review00048.dat',
#  'reviews/review00049.dat',
#  'reviews/review00050.dat',
#  'reviews/review00051.dat',
#  'reviews/review00052.dat',
#  'reviews/review00053.dat',
#  'reviews/review00054.dat',
#  'reviews/review00055.dat',
#  'reviews/review00056.dat',
#  'reviews/review00057.dat',
#  'reviews/review00058.dat',
#  'reviews/review00059.dat',
#  'reviews/review00060.dat',
#  'reviews/review00061.dat',
#  'reviews/review00062.dat',
#  'reviews/review00063.dat',
#  'reviews/review00064.dat',
#  'reviews/review00065.dat',
#  'reviews/review00066.dat',
#  'reviews/review00067.dat',
#  'reviews/review00068.dat',
#  'reviews/review00069.dat',
#  'reviews/review00070.dat',
#  'reviews/review00071.dat',
#  'reviews/review00072.dat',
#  'reviews/review00073.dat',
#  'reviews/review00074.dat',
#  'reviews/review00075.dat',
#  'reviews/review00076.dat',
#  'reviews/review00077.dat',
#  'reviews/review00078.dat',
#  'reviews/review00079.dat',
#  'reviews/review00080.dat',
#  'reviews/review00081.dat',
#  'reviews/review00082.dat',
#  'reviews/review00083.dat',
#  'reviews/review00084.dat',
#  'reviews/review00085.dat',
#  'reviews/review00086.dat',
#  'reviews/review00087.dat',
#  'reviews/review00088.dat',
#  'reviews/review00089.dat',
#  'reviews/review00090.dat',
#  'reviews/review00091.dat',
#  'reviews/review00092.dat',
#  'reviews/review00093.dat',
#  'reviews/review00094.dat',
#  'reviews/review00095.dat',
#  'reviews/review00096.dat',
#  'reviews/review00097.dat',
#  'reviews/review00098.dat',
#  'reviews/review00099.dat',
#  'reviews/review00100.dat',
#  'reviews/review00101.dat',
#  'reviews/review00102.dat',
#  'reviews/review00103.dat',
#  'reviews/review00104.dat',
#  'reviews/review00105.dat',
#  'reviews/review00106.dat',
#  'reviews/review00107.dat',
#  'reviews/review00108.dat',
#  'reviews/review00109.dat',
#  'reviews/review00110.dat',
#  'reviews/review00111.dat',
#  'reviews/review00112.dat',
#  'reviews/review00113.dat',
#  'reviews/review00114.dat',
#  'reviews/review00115.dat',
#  'reviews/review00116.dat',
#  'reviews/review00117.dat',
#  'reviews/review00118.dat',
#  'reviews/review00119.dat',
#  'reviews/review00120.dat',
#  'reviews/review00121.dat',
#  'reviews/review00122.dat',
#  'reviews/review00123.dat',
#  'reviews/review00124.dat',
#  'reviews/review00125.dat',
#  'reviews/review00126.dat',
#  'reviews/review00127.dat',
#  'reviews/review00128.dat',
#  'reviews/review00129.dat',
#  'reviews/review00130.dat',
#  'reviews/review00131.dat',
#  'reviews/review00132.dat',
#  'reviews/review00133.dat',
#  'reviews/review00134.dat',
#  'reviews/review00135.dat',
#  'reviews/review00136.dat',
#  'reviews/review00137.dat',
#  'reviews/review00138.dat',
#  'reviews/review00139.dat',
#  'reviews/review00140.dat',
#  'reviews/review00141.dat',
#  'reviews/review00142.dat',
#  'reviews/review00143.dat',
#  'reviews/review00144.dat',
#  'reviews/review00145.dat',
#  'reviews/review00146.dat',
#  'reviews/review00147.dat',
#  'reviews/review00148.dat',
#  'reviews/review00149.dat',
#  'reviews/review00150.dat',
#  'reviews/review00151.dat',
#  'reviews/review00152.dat',
#  'reviews/review00153.dat',
#  'reviews/review00154.dat',
#  'reviews/review00155.dat',
#  'reviews/review00156.dat',
#  'reviews/review00157.dat',
#  'reviews/review00158.dat',
#  'reviews/review00159.dat',
#  'reviews/review00160.dat',
#  'reviews/review00161.dat',
#  'reviews/review00162.dat',
#  'reviews/review00163.dat',
#  'reviews/review00164.dat',
#  'reviews/review00165.dat',
#  'reviews/review00166.dat',
#  'reviews/review00167.dat',
#  'reviews/review00168.dat',
#  'reviews/review00169.dat',
#  'reviews/review00170.dat',
#  'reviews/review00171.dat',
#  'reviews/review00172.dat',
#  'reviews/review00173.dat',
#  'reviews/review00174.dat',
#  'reviews/review00175.dat',
#  'reviews/review00176.dat',
#  'reviews/review00177.dat',
#  'reviews/review00178.dat',
#  'reviews/review00179.dat',
#  'reviews/review00180.dat',
#  'reviews/review00181.dat',
#  'reviews/review00182.dat',
#  'reviews/review00183.dat',
#  'reviews/review00184.dat',
#  'reviews/review00185.dat',
#  'reviews/review00186.dat',
#  'reviews/review00187.dat',
#  'reviews/review00188.dat',
#  'reviews/review00189.dat',
#  'reviews/review00190.dat',
#  'reviews/review00191.dat',
#  'reviews/review00192.dat',
#  'reviews/review00193.dat',
#  'reviews/review00194.dat',
#  'reviews/review00195.dat',
#  'reviews/review00196.dat',
#  'reviews/review00197.dat',
#  'reviews/review00198.dat',
#  'reviews/review00199.dat',
#  'reviews/review00200.dat',
#  'reviews/review00201.dat',
#  'reviews/review00202.dat',
#  'reviews/review00203.dat',
#  'reviews/review00204.dat',
#  'reviews/review00205.dat',
#  'reviews/review00206.dat',
#  'reviews/review00207.dat',
#  'reviews/review00208.dat',
#  'reviews/review00209.dat',
#  'reviews/review00210.dat',
#  'reviews/review00211.dat',
#  'reviews/review00212.dat',
#  'reviews/review00213.dat',
#  'reviews/review00214.dat',
#  'reviews/review00215.dat',
#  'reviews/review00216.dat',
#  'reviews/review00217.dat',
#  'reviews/review00218.dat',
#  'reviews/review00219.dat',
#  'reviews/review00220.dat',
#  'reviews/review00221.dat',
#  'reviews/review00222.dat',
#  'reviews/review00223.dat',
#  'reviews/review00224.dat',
#  'reviews/review00225.dat',
#  'reviews/review00226.dat',
#  'reviews/review00227.dat',
#  'reviews/review00228.dat',
#  'reviews/review00229.dat',
#  'reviews/review00230.dat',
#  'reviews/review00231.dat',
#  'reviews/review00232.dat',
#  'reviews/review00233.dat',
#  'reviews/review00234.dat',
#  'reviews/review00235.dat',
#  'reviews/review00236.dat',
#  'reviews/review00237.dat',
#  'reviews/review00238.dat',
#  'reviews/review00239.dat',
#  'reviews/review00240.dat',
#  'reviews/review00241.dat',
#  'reviews/review00242.dat',
#  'reviews/review00243.dat',
#  'reviews/review00244.dat',
#  'reviews/review00245.dat',
#  'reviews/review00246.dat',
#  'reviews/review00247.dat',
#  'reviews/review00248.dat',
#  'reviews/review00249.dat',
#  'reviews/review00250.dat',
#  'reviews/review00251.dat',
#  'reviews/review00252.dat',
#  'reviews/review00253.dat',
#  'reviews/review00254.dat',
#  'reviews/review00255.dat',
#  'reviews/review00256.dat',
#  'reviews/review00257.dat',
#  'reviews/review00258.dat',
#  'reviews/review00259.dat',
#  'reviews/review00260.dat',
#  'reviews/review00261.dat',
#  'reviews/review00262.dat',
#  'reviews/review00263.dat',
#  'reviews/review00264.dat',
#  'reviews/review00265.dat',
#  'reviews/review00266.dat',
#  'reviews/review00267.dat',
#  'reviews/review00268.dat',
#  'reviews/review00269.dat',
#  'reviews/review00270.dat',
#  'reviews/review00271.dat',
#  'reviews/review00272.dat',
#  'reviews/review00273.dat',
#  'reviews/review00274.dat',
#  'reviews/review00275.dat',
#  'reviews/review00276.dat',
#  'reviews/review00277.dat',
#  'reviews/review00278.dat',
#  'reviews/review00279.dat',
#  'reviews/review00280.dat',
#  'reviews/review00281.dat',
#  'reviews/review00282.dat',
#  'reviews/review00283.dat',
#  'reviews/review00284.dat',
#  'reviews/review00285.dat',
#  'reviews/review00286.dat',
#  'reviews/review00287.dat',
#  'reviews/review00288.dat',
#  'reviews/review00289.dat',
#  'reviews/review00290.dat',
#  'reviews/review00291.dat',
#  'reviews/review00292.dat',
#  'reviews/review00293.dat',
#  'reviews/review00294.dat',
#  'reviews/review00295.dat',
#  'reviews/review00296.dat',
#  'reviews/review00297.dat',
#  'reviews/review00298.dat',
#  'reviews/review00299.dat',
#  'reviews/review00300.dat',
#  'reviews/review00301.dat',
#  'reviews/review00302.dat',
#  'reviews/review00303.dat',
#  'reviews/review00304.dat',
#  'reviews/review00305.dat',
#  'reviews/review00306.dat',
#  'reviews/review00307.dat',
#  'reviews/review00308.dat',
#  'reviews/review00309.dat',
#  'reviews/review00310.dat',
#  'reviews/review00311.dat',
#  'reviews/review00312.dat',
#  'reviews/review00313.dat',
#  'reviews/review00314.dat',
#  'reviews/review00315.dat',
#  'reviews/review00316.dat',
#  'reviews/review00317.dat',
#  'reviews/review00318.dat',
#  'reviews/review00319.dat',
#  'reviews/review00320.dat',
#  'reviews/review00321.dat',
#  'reviews/review00322.dat',
#  'reviews/review00323.dat',
#  'reviews/review00324.dat',
#  'reviews/review00325.dat',
#  'reviews/review00326.dat',
#  'reviews/review00327.dat',
#  'reviews/review00328.dat',
#  'reviews/review00329.dat',
#  'reviews/review00330.dat',
#  'reviews/review00331.dat',
#  'reviews/review00332.dat',
#  'reviews/review00333.dat',
#  'reviews/review00334.dat',
#  'reviews/review00335.dat',
#  'reviews/review00336.dat',
#  'reviews/review00337.dat',
#  'reviews/review00338.dat',
#  'reviews/review00339.dat',
#  'reviews/review00340.dat',
#  'reviews/review00341.dat',
#  'reviews/review00342.dat',
#  'reviews/review00343.dat',
#  'reviews/review00344.dat',
#  'reviews/review00345.dat',
#  'reviews/review00346.dat',
#  'reviews/review00347.dat',
#  'reviews/review00348.dat',
#  'reviews/review00349.dat',
#  'reviews/review00350.dat',
#  'reviews/review00351.dat',
#  'reviews/review00352.dat',
#  'reviews/review00353.dat',
#  'reviews/review00354.dat',
#  'reviews/review00355.dat',
#  'reviews/review00356.dat',
#  'reviews/review00357.dat',
#  'reviews/review00358.dat',
#  'reviews/review00359.dat',
#  'reviews/review00360.dat',
#  'reviews/review00361.dat',
#  'reviews/review00362.dat',
#  'reviews/review00363.dat',
#  'reviews/review00364.dat',
#  'reviews/review00365.dat',
#  'reviews/review00366.dat',
#  'reviews/review00367.dat',
#  'reviews/review00368.dat',
#  'reviews/review00369.dat',
#  'reviews/review00370.dat',
#  'reviews/review00371.dat',
#  'reviews/review00372.dat',
#  'reviews/review00373.dat',
#  'reviews/review00374.dat',
#  'reviews/review00375.dat',
#  'reviews/review00376.dat',
#  'reviews/review00377.dat',
#  'reviews/review00378.dat',
#  'reviews/review00379.dat',
#  'reviews/review00380.dat',
#  'reviews/review00381.dat',
#  'reviews/review00382.dat',
#  'reviews/review00383.dat',
#  'reviews/review00384.dat',
#  'reviews/review00385.dat',
#  'reviews/review00386.dat',
#  'reviews/review00387.dat',
#  'reviews/review00388.dat',
#  'reviews/review00389.dat',
#  'reviews/review00390.dat',
#  'reviews/review00391.dat',
#  'reviews/review00392.dat',
#  'reviews/review00393.dat',
#  'reviews/review00394.dat',
#  'reviews/review00395.dat',
#  'reviews/review00396.dat',
#  'reviews/review00397.dat',
#  'reviews/review00398.dat',
#  'reviews/review00399.dat',
#  'reviews/review00400.dat',
#  'reviews/review00401.dat',
#  'reviews/review00402.dat',
#  'reviews/review00403.dat',
#  'reviews/review00404.dat',
#  'reviews/review00405.dat',
#  'reviews/review00406.dat',
#  'reviews/review00407.dat',
#  'reviews/review00408.dat',
#  'reviews/review00409.dat',
#  'reviews/review00410.dat',
#  'reviews/review00411.dat',
#  'reviews/review00412.dat',
#  'reviews/review00413.dat',
#  'reviews/review00414.dat',
#  'reviews/review00415.dat',
#  'reviews/review00416.dat',
#  'reviews/review00417.dat',
#  'reviews/review00418.dat',
#  'reviews/review00419.dat',
#  'reviews/review00420.dat',
#  'reviews/review00421.dat',
#  'reviews/review00422.dat',
#  'reviews/review00423.dat',
#  'reviews/review00424.dat',
#  'reviews/review00425.dat',
#  'reviews/review00426.dat',
#  'reviews/review00427.dat',
#  'reviews/review00428.dat',
#  'reviews/review00429.dat',
#  'reviews/review00430.dat',
#  'reviews/review00431.dat',
#  'reviews/review00432.dat',
#  'reviews/review00433.dat',
#  'reviews/review00434.dat',
#  'reviews/review00435.dat',
#  'reviews/review00436.dat',
#  'reviews/review00437.dat',
#  'reviews/review00438.dat',
#  'reviews/review00439.dat',
#  'reviews/review00440.dat',
#  'reviews/review00441.dat',
#  'reviews/review00442.dat',
#  'reviews/review00443.dat',
#  'reviews/review00444.dat',
#  'reviews/review00445.dat',
#  'reviews/review00446.dat',
#  'reviews/review00447.dat',
#  'reviews/review00448.dat',
#  'reviews/review00449.dat',
#  'reviews/review00450.dat',
#  'reviews/review00451.dat',
#  'reviews/review00452.dat',
#  'reviews/review00453.dat',
#  'reviews/review00454.dat',
#  'reviews/review00455.dat',
#  'reviews/review00456.dat',
#  'reviews/review00457.dat',
#  'reviews/review00458.dat',
#  'reviews/review00459.dat',
#  'reviews/review00460.dat',
#  'reviews/review00461.dat',
#  'reviews/review00462.dat',
#  'reviews/review00463.dat',
#  'reviews/review00464.dat',
#  'reviews/review00465.dat',
#  'reviews/review00466.dat',
#  'reviews/review00467.dat',
#  'reviews/review00468.dat',
#  'reviews/review00469.dat',
#  'reviews/review00470.dat',
#  'reviews/review00471.dat',
#  'reviews/review00472.dat',
#  'reviews/review00473.dat',
#  'reviews/review00474.dat',
#  'reviews/review00475.dat',
#  'reviews/review00476.dat',
#  'reviews/review00477.dat',
#  'reviews/review00478.dat',
#  'reviews/review00479.dat',
#  'reviews/review00480.dat',
#  'reviews/review00481.dat',
#  'reviews/review00482.dat',
#  'reviews/review00483.dat',
#  'reviews/review00484.dat',
#  'reviews/review00485.dat',
#  'reviews/review00486.dat',
#  'reviews/review00487.dat',
#  'reviews/review00488.dat',
#  'reviews/review00489.dat',
#  'reviews/review00490.dat',
#  'reviews/review00491.dat',
#  'reviews/review00492.dat',
#  'reviews/review00493.dat',
#  'reviews/review00494.dat',
#  'reviews/review00495.dat',
#  'reviews/review00496.dat',
#  'reviews/review00497.dat',
#  'reviews/review00498.dat',
#  'reviews/review00499.dat',
#  'reviews/review00500.dat',
#  'reviews/review00501.dat',
#  'reviews/review00502.dat',
#  'reviews/review00503.dat',
#  'reviews/review00504.dat',
#  'reviews/review00505.dat',
#  'reviews/review00506.dat',
#  'reviews/review00507.dat',
#  'reviews/review00508.dat',
#  'reviews/review00509.dat',
#  'reviews/review00510.dat',
#  'reviews/review00511.dat',
#  'reviews/review00512.dat',
#  'reviews/review00513.dat',
#  'reviews/review00514.dat',
#  'reviews/review00515.dat',
#  'reviews/review00516.dat',
#  'reviews/review00517.dat',
#  'reviews/review00518.dat',
#  'reviews/review00519.dat',
#  'reviews/review00520.dat',
#  'reviews/review00521.dat',
#  'reviews/review00522.dat',
#  'reviews/review00523.dat',
#  'reviews/review00524.dat',
#  'reviews/review00525.dat',
#  'reviews/review00526.dat',
#  'reviews/review00527.dat',
#  'reviews/review00528.dat',
#  'reviews/review00529.dat',
#  'reviews/review00530.dat',
#  'reviews/review00531.dat',
#  'reviews/review00532.dat',
#  'reviews/review00533.dat',
#  'reviews/review00534.dat',
#  'reviews/review00535.dat',
#  'reviews/review00536.dat',
#  'reviews/review00537.dat',
#  'reviews/review00538.dat',
#  'reviews/review00539.dat',
#  'reviews/review00540.dat',
#  'reviews/review00541.dat',
#  'reviews/review00542.dat',
#  'reviews/review00543.dat',
#  'reviews/review00544.dat',
#  'reviews/review00545.dat',
#  'reviews/review00546.dat',
#  'reviews/review00547.dat',
#  'reviews/review00548.dat',
#  'reviews/review00549.dat',
#  'reviews/review00550.dat',
#  'reviews/review00551.dat',
#  'reviews/review00552.dat',
#  'reviews/review00553.dat',
#  'reviews/review00554.dat',
#  'reviews/review00555.dat',
#  'reviews/review00556.dat',
#  'reviews/review00557.dat',
#  'reviews/review00558.dat',
#  'reviews/review00559.dat',
#  'reviews/review00560.dat',
#  'reviews/review00561.dat',
#  'reviews/review00562.dat',
#  'reviews/review00563.dat',
#  'reviews/review00564.dat',
#  'reviews/review00565.dat',
#  'reviews/review00566.dat',
#  'reviews/review00567.dat',
#  'reviews/review00568.dat',
#  'reviews/review00569.dat',
#  'reviews/review00570.dat',
#  'reviews/review00571.dat',
#  'reviews/review00572.dat',
#  'reviews/review00573.dat',
#  'reviews/review00574.dat',
#  'reviews/review00575.dat',
#  'reviews/review00576.dat',
#  'reviews/review00577.dat',
#  'reviews/review00578.dat',
#  'reviews/review00579.dat',
#  'reviews/review00580.dat',
#  'reviews/review00581.dat',
#  'reviews/review00582.dat',
#  'reviews/review00583.dat',
#  'reviews/review00584.dat',
#  'reviews/review00585.dat',
#  'reviews/review00586.dat',
#  'reviews/review00587.dat',
#  'reviews/review00588.dat',
#  'reviews/review00589.dat',
#  'reviews/review00590.dat',
#  'reviews/review00591.dat',
#  'reviews/review00592.dat',
#  'reviews/review00593.dat',
#  'reviews/review00594.dat',
#  'reviews/review00595.dat',
#  'reviews/review00596.dat',
#  'reviews/review00597.dat',
#  'reviews/review00598.dat',
#  'reviews/review00599.dat',
#  'reviews/review00600.dat',
#  'reviews/review00601.dat',
#  'reviews/review00602.dat',
#  'reviews/review00603.dat',
#  'reviews/review00604.dat',
#  'reviews/review00605.dat',
#  'reviews/review00606.dat',
#  'reviews/review00607.dat',
#  'reviews/review00608.dat',
#  'reviews/review00609.dat',
#  'reviews/review00610.dat',
#  'reviews/review00611.dat',
#  'reviews/review00612.dat',
#  'reviews/review00613.dat',
#  'reviews/review00614.dat',
#  'reviews/review00615.dat',
#  'reviews/review00616.dat',
#  'reviews/review00617.dat',
#  'reviews/review00618.dat',
#  'reviews/review00619.dat',
#  'reviews/review00620.dat',
#  'reviews/review00621.dat',
#  'reviews/review00622.dat',
#  'reviews/review00623.dat',
#  'reviews/review00624.dat',
#  'reviews/review00625.dat',
#  'reviews/review00626.dat',
#  'reviews/review00627.dat',
#  'reviews/review00628.dat',
#  'reviews/review00629.dat',
#  'reviews/review00630.dat',
#  'reviews/review00631.dat',
#  'reviews/review00632.dat',
#  'reviews/review00633.dat',
#  'reviews/review00634.dat',
#  'reviews/review00635.dat',
#  'reviews/review00636.dat',
#  'reviews/review00637.dat',
#  'reviews/review00638.dat',
#  'reviews/review00639.dat',
#  'reviews/review00640.dat',
#  'reviews/review00641.dat',
#  'reviews/review00642.dat',
#  'reviews/review00643.dat',
#  'reviews/review00644.dat',
#  'reviews/review00645.dat',
#  'reviews/review00646.dat',
#  'reviews/review00647.dat',
#  'reviews/review00648.dat',
#  'reviews/review00649.dat',
#  'reviews/review00650.dat',
#  'reviews/review00651.dat',
#  'reviews/review00652.dat',
#  'reviews/review00653.dat',
#  'reviews/review00654.dat',
#  'reviews/review00655.dat',
#  'reviews/review00656.dat',
#  'reviews/review00657.dat',
#  'reviews/review00658.dat',
#  'reviews/review00659.dat',
#  'reviews/review00660.dat',
#  'reviews/review00661.dat',
#  'reviews/review00662.dat',
#  'reviews/review00663.dat',
#  'reviews/review00664.dat',
#  'reviews/review00665.dat',
#  'reviews/review00666.dat',
#  'reviews/review00667.dat',
#  'reviews/review00668.dat',
#  'reviews/review00669.dat',
#  'reviews/review00670.dat',
#  'reviews/review00671.dat',
#  'reviews/review00672.dat',
#  'reviews/review00673.dat',
#  'reviews/review00674.dat',
#  'reviews/review00675.dat',
#  'reviews/review00676.dat',
#  'reviews/review00677.dat',
#  'reviews/review00678.dat',
#  'reviews/review00679.dat',
#  'reviews/review00680.dat',
#  'reviews/review00681.dat',
#  'reviews/review00682.dat',
#  'reviews/review00683.dat',
#  'reviews/review00684.dat',
#  'reviews/review00685.dat',
#  'reviews/review00686.dat',
#  'reviews/review00687.dat',
#  'reviews/review00688.dat',
#  'reviews/review00689.dat',
#  'reviews/review00690.dat',
#  'reviews/review00691.dat',
#  'reviews/review00692.dat',
#  'reviews/review00693.dat',
#  'reviews/review00694.dat',
#  'reviews/review00695.dat',
#  'reviews/review00696.dat',
#  'reviews/review00697.dat',
#  'reviews/review00698.dat',
#  'reviews/review00699.dat',
#  'reviews/review00700.dat',
#  'reviews/review00701.dat',
#  'reviews/review00702.dat',
#  'reviews/review00703.dat',
#  'reviews/review00704.dat',
#  'reviews/review00705.dat',
#  'reviews/review00706.dat',
#  'reviews/review00707.dat',
#  'reviews/review00708.dat',
#  'reviews/review00709.dat',
#  'reviews/review00710.dat',
#  'reviews/review00711.dat',
#  'reviews/review00712.dat',
#  'reviews/review00713.dat',
#  'reviews/review00714.dat',
#  'reviews/review00715.dat',
#  'reviews/review00716.dat',
#  'reviews/review00717.dat',
#  'reviews/review00718.dat',
#  'reviews/review00719.dat',
#  'reviews/review00720.dat',
#  'reviews/review00721.dat',
#  'reviews/review00722.dat',
#  'reviews/review00723.dat',
#  'reviews/review00724.dat',
#  'reviews/review00725.dat',
#  'reviews/review00726.dat',
#  'reviews/review00727.dat',
#  'reviews/review00728.dat',
#  'reviews/review00729.dat',
#  'reviews/review00730.dat',
#  'reviews/review00731.dat',
#  'reviews/review00732.dat',
#  'reviews/review00733.dat',
#  'reviews/review00734.dat',
#  'reviews/review00735.dat',
#  'reviews/review00736.dat',
#  'reviews/review00737.dat',
#  'reviews/review00738.dat',
#  'reviews/review00739.dat',
#  'reviews/review00740.dat',
#  'reviews/review00741.dat',
#  'reviews/review00742.dat',
#  'reviews/review00743.dat',
#  'reviews/review00744.dat',
#  'reviews/review00745.dat',
#  'reviews/review00746.dat',
#  'reviews/review00747.dat',
#  'reviews/review00748.dat',
#  'reviews/review00749.dat',
#  'reviews/review00750.dat',
#  'reviews/review00751.dat',
#  'reviews/review00752.dat',
#  'reviews/review00753.dat',
#  'reviews/review00754.dat',
#  'reviews/review00755.dat',
#  'reviews/review00756.dat',
#  'reviews/review00757.dat',
#  'reviews/review00758.dat',
#  'reviews/review00759.dat',
#  'reviews/review00760.dat',
#  'reviews/review00761.dat',
#  'reviews/review00762.dat',
#  'reviews/review00763.dat',
#  'reviews/review00764.dat',
#  'reviews/review00765.dat',
#  'reviews/review00766.dat',
#  'reviews/review00767.dat',
#  'reviews/review00768.dat',
#  'reviews/review00769.dat',
#  'reviews/review00770.dat',
#  'reviews/review00771.dat',
#  'reviews/review00772.dat',
#  'reviews/review00773.dat',
#  'reviews/review00774.dat',
#  'reviews/review00775.dat',
#  'reviews/review00776.dat',
#  'reviews/review00777.dat',
#  'reviews/review00778.dat',
#  'reviews/review00779.dat',
#  'reviews/review00780.dat',
#  'reviews/review00781.dat',
#  'reviews/review00782.dat',
#  'reviews/review00783.dat',
#  'reviews/review00784.dat',
#  'reviews/review00785.dat',
#  'reviews/review00786.dat',
#  'reviews/review00787.dat',
#  'reviews/review00788.dat',
#  'reviews/review00789.dat',
#  'reviews/review00790.dat',
#  'reviews/review00791.dat',
#  'reviews/review00792.dat',
#  'reviews/review00793.dat',
#  'reviews/review00794.dat',
#  'reviews/review00795.dat',
#  'reviews/review00796.dat',
#  'reviews/review00797.dat',
#  'reviews/review00798.dat',
#  'reviews/review00799.dat',
#  'reviews/review00800.dat',
#  'reviews/review00801.dat',
#  'reviews/review00802.dat',
#  'reviews/review00803.dat',
#  'reviews/review00804.dat',
#  'reviews/review00805.dat',
#  'reviews/review00806.dat',
#  'reviews/review00807.dat',
#  'reviews/review00808.dat',
#  'reviews/review00809.dat',
#  'reviews/review00810.dat',
#  'reviews/review00811.dat',
#  'reviews/review00812.dat',
#  'reviews/review00813.dat',
#  'reviews/review00814.dat',
#  'reviews/review00815.dat',
#  'reviews/review00816.dat',
#  'reviews/review00817.dat',
#  'reviews/review00818.dat',
#  'reviews/review00819.dat',
#  'reviews/review00820.dat',
#  'reviews/review00821.dat',
#  'reviews/review00822.dat',
#  'reviews/review00823.dat',
#  'reviews/review00824.dat',
#  'reviews/review00825.dat',
#  'reviews/review00826.dat',
#  'reviews/review00827.dat',
#  'reviews/review00828.dat',
#  'reviews/review00829.dat',
#  'reviews/review00830.dat',
#  'reviews/review00831.dat',
#  'reviews/review00832.dat',
#  'reviews/review00833.dat',
#  'reviews/review00834.dat',
#  'reviews/review00835.dat',
#  'reviews/review00836.dat',
#  'reviews/review00837.dat',
#  'reviews/review00838.dat',
#  'reviews/review00839.dat',
#  'reviews/review00840.dat',
#  'reviews/review00841.dat',
#  'reviews/review00842.dat',
#  'reviews/review00843.dat',
#  'reviews/review00844.dat',
#  'reviews/review00845.dat',
#  'reviews/review00846.dat',
#  'reviews/review00847.dat',
#  'reviews/review00848.dat',
#  'reviews/review00849.dat',
#  'reviews/review00850.dat',
#  'reviews/review00851.dat',
#  'reviews/review00852.dat',
#  'reviews/review00853.dat',
#  'reviews/review00854.dat',
#  'reviews/review00855.dat',
#  'reviews/review00856.dat',
#  'reviews/review00857.dat',
#  'reviews/review00858.dat',
#  'reviews/review00859.dat',
#  'reviews/review00860.dat',
#  'reviews/review00861.dat',
#  'reviews/review00862.dat',
#  'reviews/review00863.dat',
#  'reviews/review00864.dat',
#  'reviews/review00865.dat',
#  'reviews/review00866.dat',
#  'reviews/review00867.dat',
#  'reviews/review00868.dat',
#  'reviews/review00869.dat',
#  'reviews/review00870.dat',
#  'reviews/review00871.dat',
#  'reviews/review00872.dat',
#  'reviews/review00873.dat',
#  'reviews/review00874.dat',
#  'reviews/review00875.dat',
#  'reviews/review00876.dat',
#  'reviews/review00877.dat',
#  'reviews/review00878.dat',
#  'reviews/review00879.dat',
#  'reviews/review00880.dat',
#  'reviews/review00881.dat',
#  'reviews/review00882.dat',
#  'reviews/review00883.dat',
#  'reviews/review00884.dat',
#  'reviews/review00885.dat',
#  'reviews/review00886.dat',
#  'reviews/review00887.dat',
#  'reviews/review00888.dat',
#  'reviews/review00889.dat',
#  'reviews/review00890.dat',
#  'reviews/review00891.dat',
#  'reviews/review00892.dat',
#  'reviews/review00893.dat',
#  'reviews/review00894.dat',
#  'reviews/review00895.dat',
#  'reviews/review00896.dat',
#  'reviews/review00897.dat',
#  'reviews/review00898.dat',
#  'reviews/review00899.dat',
#  'reviews/review00900.dat',
#  'reviews/review00901.dat',
#  'reviews/review00902.dat',
#  'reviews/review00903.dat',
#  'reviews/review00904.dat',
#  'reviews/review00905.dat',
#  'reviews/review00906.dat',
#  'reviews/review00907.dat',
#  'reviews/review00908.dat',
#  'reviews/review00909.dat',
#  'reviews/review00910.dat',
#  'reviews/review00911.dat',
#  'reviews/review00912.dat',
#  'reviews/review00913.dat',
#  'reviews/review00914.dat',
#  'reviews/review00915.dat',
#  'reviews/review00916.dat',
#  'reviews/review00917.dat',
#  'reviews/review00918.dat',
#  'reviews/review00919.dat',
#  'reviews/review00920.dat',
#  'reviews/review00921.dat',
#  'reviews/review00922.dat',
#  'reviews/review00923.dat',
#  'reviews/review00924.dat',
#  'reviews/review00925.dat',
#  'reviews/review00926.dat',
#  'reviews/review00927.dat',
#  'reviews/review00928.dat',
#  'reviews/review00929.dat',
#  'reviews/review00930.dat',
#  'reviews/review00931.dat',
#  'reviews/review00932.dat',
#  'reviews/review00933.dat',
#  'reviews/review00934.dat',
#  'reviews/review00935.dat',
#  'reviews/review00936.dat',
#  'reviews/review00937.dat',
#  'reviews/review00938.dat',
#  'reviews/review00939.dat',
#  'reviews/review00940.dat',
#  'reviews/review00941.dat',
#  'reviews/review00942.dat',
#  'reviews/review00943.dat',
#  'reviews/review00944.dat',
#  'reviews/review00945.dat',
#  'reviews/review00946.dat',
#  'reviews/review00947.dat',
#  'reviews/review00948.dat',
#  'reviews/review00949.dat',
#  'reviews/review00950.dat',
#  'reviews/review00951.dat',
#  'reviews/review00952.dat',
#  'reviews/review00953.dat',
#  'reviews/review00954.dat',
#  'reviews/review00955.dat',
#  'reviews/review00956.dat',
#  'reviews/review00957.dat',
#  'reviews/review00958.dat',
#  'reviews/review00959.dat',
#  'reviews/review00960.dat',
#  'reviews/review00961.dat',
#  'reviews/review00962.dat',
#  'reviews/review00963.dat',
#  'reviews/review00964.dat',
#  'reviews/review00965.dat',
#  'reviews/review00966.dat',
#  'reviews/review00967.dat',
#  'reviews/review00968.dat',
#  'reviews/review00969.dat',
#  'reviews/review00970.dat',
#  'reviews/review00971.dat',
#  'reviews/review00972.dat',
#  'reviews/review00973.dat',
#  'reviews/review00974.dat',
#  'reviews/review00975.dat',
#  'reviews/review00976.dat',
#  'reviews/review00977.dat',
#  'reviews/review00978.dat',
#  'reviews/review00979.dat',
#  'reviews/review00980.dat',
#  'reviews/review00981.dat',
#  'reviews/review00982.dat',
#  'reviews/review00983.dat',
#  'reviews/review00984.dat',
#  'reviews/review00985.dat',
#  'reviews/review00986.dat',
#  'reviews/review00987.dat',
#  'reviews/review00988.dat',
#  'reviews/review00989.dat',
#  'reviews/review00990.dat',
#  'reviews/review00991.dat',
#  'reviews/review00992.dat',
#  'reviews/review00993.dat',
#  'reviews/review00994.dat',
#  'reviews/review00995.dat',
#  'reviews/review00996.dat',
#  'reviews/review00997.dat',
#  'reviews/review00998.dat',
#  'reviews/review00999.dat',
#  ...]

# %%
# load each file separately then process it
custs = []
invs  = []
prods = []
for review_file in list_of_files[0:1000]:
    #print( 'Loading', review_file )
    rev = pd.read_csv(review_file,names=['values'],delimiter=':')
    custs.append(rev['values'].loc['Customer ID'][1:])
    invs.append( rev['values'].loc['Invoice ID'][1:])
    prods.append(int(rev['values'].loc['Product Rating'][1:].split('/')[0]))

# %%
my_dict = {
    'Customer_id':custs,
    'Invoice_id' : invs,
    'Product_rating': prods
}

# %%
ratings = pd.DataFrame.from_dict(my_dict)

# %%
ratings.tail()
# Out:
#     Customer_id    Invoice_id  Product_rating
# 995        5881  S28074900064               4
# 996        4678  S05268900002               2
# 997        2406  S23117400013               2
# 998        4584  S14636100039               5
# 999        4973  S13774200034               5

# %%
ratings.to_csv('reviews-out.csv')

# %% [markdown]
# ### Merging the Database

# %% [markdown]
# Once the data have been loaded into three separate tables, which I will here call `invoices`, `items`, and `reviews`, **you should merge them into each other.**  Your two master records are the invoices, which should never change in number, and the reviews, which are similarly fixed.  The item data can be combined with those.
#
# If using Pandas, you should use a `left` join on `invoices` with `items`.
#
# If using SQL, you should left-join `invoices` to `items`.
#
# This should yield a merged database, `invoices_all`, which contains the invoices as records and includes information about each item sold.
#
# Do the same for the reviews with the item data in `reviews_all`, except that you should `left` join on `reviews` with `invoices`, as not all invoice purchases generated reviews.  You should verify that you can obtain item IDs and rating numbers from the same database, as that will be necessary for the recommendation engine step below.
#
# _(If you need help with this step, reach out to me.  That offer stands for all of this, but this step is perhaps more complicated than some others.)_

# %%
invoices = pd.read_csv('data_code/invoice.csv')
items = pd.read_csv('data_code/item.csv')
reviews = pd.read_csv('reviews-out.csv', usecols = ['Customer_id','Invoice_id', 'Product_rating']) 

invoices_all = pd.merge(invoices, items, on='Item_id', how='left')
reviews_all = pd.merge(reviews, invoices_all, on="Invoice_id", how='left')

reviews_all
# Out:
#      Customer_id       Invoice_id  Product_rating        Date  Item_id  \
# 0           2383     S11999300004               2  2013-05-02    89196
# 1           9192     S05392500012               3  2012-05-08    58836
# 2           4847     S18588700081               3  2014-04-23    73702
# 3           4288     S34002200005               1  2016-08-18    35916
# 4           1193     S10611300016               4  2013-02-14    26821
# 5           9098  INV-08323600020               4  2017-10-30    36969
# 6           1910     S26275400080               2  2015-06-18    43328
# 7           9810     S13412800074               4  2013-07-17    35948
# 8           9937     S31340000035               5  2016-03-21    43316
# 9           9256     S08435100019               5  2012-10-18    37993
# 10          9485     S24482700006               5  2015-03-11    68039
# 11          7032     S10300500004               3  2013-01-29    11294
# 12          6493     S22719700091               4  2014-12-03    89198
# 13          2768     S32853300016               3  2016-06-15    36901
# 14          3279  INV-08684500086               2  2017-11-15    45278
# 15          1384     S22918500001               4  2014-12-15    36904
# 16          1461     S29149900012               4  2015-11-18    52596
# 17          2370     S06597100021               1  2012-07-16    37356
# 18          4976     S21269100062               3  2014-09-17    77318
# 19          4288  INV-09293200001               5  2017-12-18    88294
# 20          7624     S12253500046               2  2013-05-16    69636
# 21          3867     S16807300003               1  2014-01-13    52594
# 22          6206     S05929500031               3  2012-06-06    17956
# 23          1050     S17485500083               3  2014-02-19    42006
# 24          4028     S19700400023               5  2014-06-23    43334
# 25          3398  INV-06992000013               2  2017-08-30    37996
# 26          3007     S04483600038               2  2012-03-12    88291
# 27          2054     S13407100183               2  2013-07-17    43031
# 28          8924  INV-01212300022               1  2016-10-27    37994
# 29          3837     S09012700125               5  2012-11-16    84166
# ..           ...              ...             ...         ...      ...
# 970         1890     S27533200032               5  2015-08-26    65258
# 971         3007  INV-02168000012               2  2016-12-15    37938
# 972         9202     S18322500124               5  2014-04-09    89200
# 973         1055  INV-02677700027               5  2017-01-12    24453
# 974         1136     S23448100018               1  2015-01-13    16516
# 975         7774     S30173500093               2  2016-01-13    41604
# 976         5712     S08697400001               1  2012-10-31    68047
# 977         1070     S20787000147               3  2014-08-21    50686
# 978         9784     S24504100014               5  2015-03-12    58875
# 979         8281  INV-01870100018               1  2016-11-30    68036
# 980         9071     S23303100012               3  2015-01-05    52591
# 981         3796     S29410800110               2  2015-12-02    73526
# 982         5362     S26804900055               4  2015-07-16    34395
# 983         7729     S19616100046               1  2014-06-18    64864
# 984         9009     S32391600027               3  2016-05-18    36969
# 985         8802  INV-05518200006               2  2017-06-14    43127
# 986         9325  INV-04463000158               4  2017-04-19    78866
# 987         3752     S33147500044               4  2016-06-30    34006
# 988         8849     S29304100155               3  2015-11-24    37348
# 989         2852     S08248000144               1  2012-10-10    86883
# 990         6550     S15107300028               3  2013-10-14    53214
# 991         7545     S20637300007               1  2014-08-13    35914
# 992         6845     S29398400058               1  2015-12-02    37348
# 993         5452     S17740400129               4  2014-03-05    37347
# 994         3776     S08448000005               3  2012-10-23    11297
# 995         5881     S28074900064               4  2015-09-23    54436
# 996         4678     S05268900002               2  2012-04-30    73050
# 997         2406     S23117400013               2  2014-12-22    43026
# 998         4584     S14636100039               5  2013-09-18    89199
# 999         4973     S13774200034               5  2013-08-07    42716
#
#      Vendor_id          Vendor_Name  Store_id  \
# 0          395     Mankanshoku Inc.      4072
# 1          395     Mankanshoku Inc.      3858
# 2          259         Inaba Brands      2637
# 3          297        Katou Company      4694
# 4           85  Ayuzawa Corporation      4076
# 5          205           Harima Co.      4962
# 6          260      Inuyasha Brands      3731
# 7           55       Arlert Company      2637
# 8          260      Inuyasha Brands      2554
# 9          260      Inuyasha Brands      3918
# 10         260      Inuyasha Brands      2614
# 11         260      Inuyasha Brands      3858
# 12         395     Mankanshoku Inc.      3820
# 13         300    Katsuragi Company      4588
# 14         434           Minami LLC      2637
# 15         300    Katsuragi Company      3882
# 16         205           Harima Co.      4652
# 17         380           Le Company      2623
# 18         322        Koizumi Group      2621
# 19         410      Megumin Company      5198
# 20         421        Midoriya Inc.      4638
# 21         205           Harima Co.      4652
# 22         259         Inaba Brands      4202
# 23         461      Mustang Company      2635
# 24         260      Inuyasha Brands      4612
# 25         260      Inuyasha Brands      4200
# 26         410      Megumin Company      4588
# 27          35          Archer Inc.      2614
# 28         260      Inuyasha Brands      5029
# 29          55       Arlert Company      2623
# ..         ...                  ...       ...
# 970        192            Gokou Co.      3757
# 971         55       Arlert Company      3540
# 972        260      Inuyasha Brands      2625
# 973         65       Ayanami Brands      2567
# 974        421        Midoriya Inc.      4202
# 975        380           Le Company      2623
# 976        260      Inuyasha Brands      2594
# 977        389          Littner LLC      2567
# 978        395     Mankanshoku Inc.      2838
# 979        260      Inuyasha Brands      4568
# 980        205           Harima Co.      3805
# 981         65       Ayanami Brands      2623
# 982         65       Ayanami Brands      2635
# 983        421        Midoriya Inc.      4588
# 984        205           Harima Co.      2623
# 985         35          Archer Inc.      3447
# 986        434           Minami LLC      2623
# 987        370            Kyon Inc.      3731
# 988        380           Le Company      2635
# 989         85  Ayuzawa Corporation      2594
# 990        115        Deviluke Inc.      3805
# 991        297        Katou Company      4879
# 992        380           Le Company      3757
# 993        380           Le Company      2625
# 994        260      Inuyasha Brands      3354
# 995         55       Arlert Company      3820
# 996        305         Kinomoto Ltd      3986
# 997        259         Inaba Brands      4879
# 998        395     Mankanshoku Inc.      2567
# 999        370            Kyon Inc.      3722
#
#                                Store_Name                  Address  \
# 0                             Famous Durg         2604 W LOCUST ST
# 1         Harolds Jack N Jill / Davenport      6723 NW BLVD UNIT 2
# 2                   Hy-Vee #5 / Davenport            2351 W LOCUST
# 3               Rina Mart LLC / Davenport   3815, WEST KIMBERLY RD
# 4                        Sakar Durg Store       1026 W RIVER DR #B
# 5                         Hilltop Grocery         1312 HARRISON ST
# 6               Wal-Mart 1241 / Davenport          5811 ELMORE AVE
# 7                   Hy-Vee #5 / Davenport            2351 W LOCUST
# 8           Hy-Vee Food Store / Davenport     3019 ROCKINGHAM ROAD
# 9          Smokin' Joe's #1 Food and Durg       3120 ROCKINGHAM RD
# 10           Hy-Vee #3 Food and Drugstore       1823 E KIMBERLY RD
# 11        Harolds Jack N Jill / Davenport      6723 NW BLVD UNIT 2
# 12           Charlie's Convenience Store,            507 W 19th St
# 13           Sam's Mini Mart / Sioux City            923, W 7TH ST
# 14                  Hy-Vee #5 / Davenport            2351 W LOCUST
# 15             Kwik Shop #579 / Davenport        2805 TELEGRAPH RD
# 16                 Brady Mart Food & Durg           3107, BRADY ST
# 17      Hy-Vee Food Store #4 / Sioux City       2827 HAMILTON BLVD
# 18      Hy-Vee Food Store #3 / Sioux City           3301 GORDON DR
# 19                         Riverside Durg           826 E RIVER DR
# 20                  GD Xpress / Davenport           4607 N PINE ST
# 21                 Brady Mart Food & Durg           3107, BRADY ST
# 22       Fareway Stores #829 / Sioux City         4267 SERGEANT RD
# 23                  Hy-Vee #4 / Davenport           4064 E 53RD ST
# 24                               ATC Durg           214, MYRTLE ST
# 25       Fareway Stores #019 / Sioux City     4016 INDIAN HILLS DR
# 26           Sam's Mini Mart / Sioux City            923, W 7TH ST
# 27           Hy-Vee #3 Food and Drugstore       1823 E KIMBERLY RD
# 28                      The Durg Stop LLC           211, W 53RD ST
# 29      Hy-Vee Food Store #4 / Sioux City       2827 HAMILTON BLVD
# ..                                    ...                      ...
# 970            Wal-Mart 3590 / Sioux City          3101 FLOYD BLVD
# 971       Super Target T-0533 / Davenport          5225 ELMORE AVE
# 972           Hy-Vee Convenience Store #2       3301 W KIMBERLY RD
# 973          Hy-Vee Drugstore / Davenport       2200 WEST KIMBERLY
# 974      Fareway Stores #829 / Sioux City         4267 SERGEANT RD
# 975     Hy-Vee Food Store #4 / Sioux City       2827 HAMILTON BLVD
# 976        Hy-Vee Food Store / Sioux City       4500 SERGEANT ROAD
# 977          Hy-Vee Drugstore / Davenport       2200 WEST KIMBERLY
# 978        CVS Pharmacy #8658 / Davenport       1655 W KIMBERLY RD
# 979              Select Mart   Floyd Blvd          4103 FLOYD BLVD
# 980           Washington Street Mini Mart       1601 WASHINGTON ST
# 981     Hy-Vee Food Store #4 / Sioux City       2827 HAMILTON BLVD
# 982                 Hy-Vee #4 / Davenport           4064 E 53RD ST
# 983          Sam's Mini Mart / Sioux City            923, W 7TH ST
# 984     Hy-Vee Food Store #4 / Sioux City       2827 HAMILTON BLVD
# 985          Sam's Club 6432 / Sioux City         4201 S. YORK ST.
# 986     Hy-Vee Food Store #4 / Sioux City       2827 HAMILTON BLVD
# 987             Wal-Mart 1241 / Davenport          5811 ELMORE AVE
# 988                 Hy-Vee #4 / Davenport           4064 E 53RD ST
# 989        Hy-Vee Food Store / Sioux City       4500 SERGEANT ROAD
# 990           Washington Street Mini Mart       1601 WASHINGTON ST
# 991  Sam's Mini Mart / Morningside Ave Si     4218 MORNINGSIDE AVE
# 992            Wal-Mart 3590 / Sioux City          3101 FLOYD BLVD
# 993           Hy-Vee Convenience Store #2       3301 W KIMBERLY RD
# 994           Sam's Club 8238 / Davenport         3845 ELMORE AVE.
# 995          Charlie's Convenience Store,            507 W 19th St
# 996                    Siouxland Beverage                1203 5 ST
# 997  Sam's Mini Mart / Morningside Ave Si     4218 MORNINGSIDE AVE
# 998          Hy-Vee Drugstore / Davenport       2200 WEST KIMBERLY
# 999            Wal-Mart 1361 / Sioux City  3400 SINGING HILLS BLVD
#
#             ...          Zip_Code  County_id  County_Name Bottles_Sold  \
# 0           ...             52804         82        Scott           12
# 1           ...             52806         82        Scott           12
# 2           ...             52804         82        Scott           12
# 3           ...             52806         82        Scott           12
# 4           ...             52802         82        Scott            2
# 5           ...             52803         82        Scott           12
# 6           ...             52807         82        Scott           12
# 7           ...             52804         82        Scott           12
# 8           ...             52802         82        Scott            1
# 9           ...             52802         82        Scott            4
# 10          ...             52807         82        Scott            4
# 11          ...             52806         82        Scott           24
# 12          ...             51103         97     Woodbury            6
# 13          ...             51103         97     Woodbury            6
# 14          ...             52804         82        Scott            3
# 15          ...             52802         82        Scott           48
# 16          ...             52803         82        Scott           24
# 17          ...             51104         97     Woodbury           12
# 18          ...             51105         97     Woodbury            6
# 19          ...             52803         82        Scott            3
# 20          ...             52804         82        Scott            2
# 21          ...             52803         82        Scott           24
# 22          ...             51106         97     Woodbury            3
# 23          ...             52807         82        Scott            4
# 24          ...             52802         82        Scott           24
# 25          ...             51108         97     Woodbury            1
# 26          ...             51103         97     Woodbury            3
# 27          ...             52807         82        Scott            2
# 28          ...             52806         82        Scott            1
# 29          ...             51104         97     Woodbury            3
# ..          ...               ...        ...          ...          ...
# 970         ...             51108         97     Woodbury            6
# 971         ...             52807         82        Scott            1
# 972         ...             52804         82        Scott            1
# 973         ...             52806         82        Scott            4
# 974         ...             51106         97     Woodbury            4
# 975         ...             51104         97     Woodbury            3
# 976         ...             51106         97     Woodbury           12
# 977         ...             52806         82        Scott            2
# 978         ...             52806         82        Scott            6
# 979         ...             51108         97     Woodbury            1
# 980         ...             52084         82        Scott           12
# 981         ...             51104         97     Woodbury           12
# 982         ...             52807         82        Scott            6
# 983         ...             51103         97     Woodbury            4
# 984         ...             51104         97     Woodbury           12
# 985         ...             51106         97     Woodbury            1
# 986         ...             51104         97     Woodbury            2
# 987         ...             52807         82        Scott           12
# 988         ...             52807         82        Scott           30
# 989         ...             51106         97     Woodbury            1
# 990         ...             52084         82        Scott           48
# 991         ...             51106         97     Woodbury           24
# 992         ...             51108         97     Woodbury            6
# 993         ...             52804         82        Scott          132
# 994         ...             52807         82        Scott          120
# 995         ...             51103         97     Woodbury            2
# 996         ...             51101         97     Woodbury            6
# 997         ...             51106         97     Woodbury           12
# 998         ...             52806         82        Scott           12
# 999         ...             51106         97     Woodbury           12
#
#                        Item_Description      Category Pack  Bottle_Volume_ml  \
# 0                         Hisoka's Cola          Cola   12             750.0
# 1                         Shinji's Lime     Lime Soda   12             750.0
# 2                 Alucard's Ginger Soda    Ginger Ale   12             750.0
# 3    Haruko's Gourmet Black Cherry Soda   Cherry Soda   12             750.0
# 4             Killua's Watermelon Cream    Cream Soda   12             500.0
# 5      Holo's Gourmet Black Cherry Soda   Cherry Soda   12             750.0
# 6               Archer's Energy Booster  Energy Drink   12             750.0
# 7      Hei's Family Secret Black Cherry   Cherry Soda    6            1750.0
# 8                       Kyouko's Energy  Energy Drink   12             750.0
# 9                    Ippo's Wild Cherry   Cherry Soda   48             200.0
# 10                Dia's Craft Root Beer     Root Beer    4            2400.0
# 11             Mayoi's Watermelon Cream    Cream Soda   24             375.0
# 12                        Hisoka's Kola          Cola    6            1750.0
# 13                     Hisoka's Red Pop   Cherry Soda    6             500.0
# 14                       Dante's Energy  Energy Drink    6            1750.0
# 15   Hitagi's Gourmet Black Cherry Soda   Cherry Soda   24             375.0
# 16                 Haruko's Orange Soda   Orange Soda   12             750.0
# 17    Howl's Family Secret Black Cherry   Cherry Soda   12             750.0
# 18             Megumin's Energy Booster  Energy Drink    6            1750.0
# 19                      Griffith's Cola          Cola   12             375.0
# 20                   Nagisa's Root Beer     Root Beer   12             750.0
# 21                 Hanayo's Orange Soda   Orange Soda   24             375.0
# 22               Gon's Watermelon Cream    Cream Soda   12             750.0
# 23                 Roy's Energy Booster  Energy Drink   12             750.0
# 24                Lain's Energy Booster  Energy Drink   24             375.0
# 25                 Issei's Black Cherry   Cherry Soda   12             750.0
# 26                 Grimmjow's Cane Cola          Cola   10             300.0
# 27              Ryuuko's Energy Booster  Energy Drink   12             500.0
# 28    Issei's Gourmet Black Cherry Soda   Cherry Soda   24             375.0
# 29             Mikasa's Craft Root Beer     Root Beer   12             750.0
# ..                                  ...           ...  ...               ...
# 970                 Gokuu's Ginger Soda    Ginger Ale    6            1750.0
# 971                  Inuyasha's Red Pop   Cherry Soda    6            1750.0
# 972                       Hitagi's Kola          Cola    6             750.0
# 973         Archer's Vanilla Cream Soda    Cream Soda   48             200.0
# 974  Esdeath's Old Fashioned Cream Soda    Cream Soda   12             750.0
# 975               Mashiro's Wild Cherry   Cherry Soda   12             750.0
# 976                 Eikichi's Root Beer     Root Beer   12             750.0
# 977                 Rikka's Orange Soda   Orange Soda   12             750.0
# 978                        Shiro's Lime     Lime Soda    6            1750.0
# 979                 Deishuu's Root Beer     Root Beer   12             750.0
# 980              Hachiman's Orange Soda   Orange Soda   12             500.0
# 981                Chitoge's Ginger Ale    Ginger Ale   12             750.0
# 982                Spike's Black Cherry   Cherry Soda    6             750.0
# 983                 Saitama's Root Beer     Root Beer   24             375.0
# 984    Holo's Gourmet Black Cherry Soda   Cherry Soda   12             750.0
# 985                   Alphonse's Energy  Energy Drink   12            1000.0
# 986             Issei's Craft Root Beer     Root Beer   12             750.0
# 987                      Riko's Red Pop   Cherry Soda   12             750.0
# 988                 Howl's Black Cherry   Cherry Soda    6            1750.0
# 989            Shouko's Craft Root Beer     Root Beer   48             200.0
# 990                  Howl's Orange Soda   Orange Soda   24             375.0
# 991                Haruhi's Wild Cherry   Cherry Soda   24             375.0
# 992                 Howl's Black Cherry   Cherry Soda    6            1750.0
# 993    Howl's Gourmet Black Cherry Soda   Cherry Soda   12            1000.0
# 994   Mayuri's Old Fashioned Cream Soda    Cream Soda   12            1000.0
# 995                Kagura's Orange Soda   Orange Soda   12             750.0
# 996                 Esdeath's Root Beer     Root Beer    6             750.0
# 997             Kotori's Energy Booster  Energy Drink   12             750.0
# 998                         Holo's Cola          Cola   12             375.0
# 999                   Hachiman's Energy  Energy Drink   12             750.0
#
#      Bottle_Cost  Bottle_Retail_Price
# 0           2.98                 4.47
# 1           2.15                 3.22
# 2           2.62                 3.93
# 3           1.97                 2.96
# 4           2.78                 4.17
# 5           2.47                 3.70
# 6           2.77                 4.16
# 7           2.51                 3.76
# 8           3.11                 4.67
# 9           1.85                 2.78
# 10          5.55                 8.33
# 11          2.58                 3.87
# 12          4.35                 6.52
# 13          2.16                 3.24
# 14          2.57                 3.85
# 15          1.75                 2.62
# 16          2.33                 3.50
# 17          2.00                 3.00
# 18          2.91                 4.36
# 19          3.47                 5.20
# 20          2.72                 4.08
# 21          1.95                 2.92
# 22          2.47                 3.70
# 23          2.98                 4.47
# 24          2.11                 3.16
# 25          2.66                 3.99
# 26          4.36                 6.54
# 27          2.28                 3.42
# 28          2.17                 3.26
# 29          2.84                 4.26
# ..           ...                  ...
# 970         5.17                 7.76
# 971         2.41                 3.74
# 972         6.07                 9.10
# 973         1.76                 2.64
# 974         2.37                 3.56
# 975         2.42                 3.63
# 976         3.33                 5.00
# 977         2.49                 3.74
# 978         2.98                 4.47
# 979         3.37                 5.06
# 980         2.33                 3.50
# 981         2.39                 3.58
# 982         3.35                 5.03
# 983         2.25                 3.38
# 984         2.47                 3.70
# 985         2.83                 4.24
# 986         2.16                 3.24
# 987         3.03                 4.54
# 988         2.57                 3.86
# 989         1.85                 2.78
# 990         1.93                 2.89
# 991         1.77                 2.66
# 992         2.57                 3.86
# 993         2.10                 3.15
# 994         4.07                 6.10
# 995         2.13                 3.19
# 996         3.26                 4.89
# 997         2.31                 3.47
# 998         2.28                 3.42
# 999         2.56                 3.84
#
# [1000 rows x 21 columns]

# %% [markdown]
# ## Statistical Analysis of the Invoices

# %% [markdown]
# Your manager wants you to take a look at the invoices and see if there's anything useful, salesworthy, or _fishy_ about them.  Now that you have a data table containing the invoices and item data, you are in a good situation to statistically analyze the values involved.
#
# First off, **decide which fields should be examined statistically.**  Does it make sense to correlate against, say, bottle volume?  Number of items in a pack?  Price?  Justify your decisions.
#
# Next, **carry out a basic statistical analysis looking for anomalies and outliers.**  These are loosely defined, but if you don't have a background in statistics, let's say that it's a value that lies at least four standard deviations from the mean, which means it should occur less than 6 in 100,000 times in a data set (0.006% likelihood).
#
# This step is well-suited to Python, in particular the [`scipy.stats` module](https://docs.scipy.org/doc/scipy/reference/stats.html).  If your data tables are in SQL, load them into Python via the PySQL interface.

# %% [markdown]
# For instance, a Python-based $t$-test, looking at the likelihood of correlation, could be written as

# %%
df_cs = reviews_all[reviews_all['Category'] == 'Cream Soda']
df_rb = reviews_all[reviews_all['Category'] == 'Root Beer']

from scipy import stats
stats.ttest_ind(df_cs['Rating'],df_rb['Rating'],equal_var=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a41c75a717fd> in <module>()
# ----> 1 df_cs = reviews_all[reviews_all['Category'] == 'Cream Soda']
#       2 df_rb = reviews_all[reviews_all['Category'] == 'Root Beer']
#       3
#       4 from scipy import stats
#       5 stats.ttest_ind(df_cs['Rating'],df_rb['Rating'],equal_var=False)
#
# NameError: name 'reviews_all' is not defined

# %% [markdown]
# In the result, the `pvalue` parameter is lower than $p=0.05$ if there is statistically significant correlation, greater than 0.05 otherwise.

# %% [markdown]
# Besides a quick look at correlations across categories, you should look at the statistical range and any outliers.  For instance, to check for outliers in items sold, we can get the standard deviation and look for records beyond our threshold:

# %%
avg = invoices_all['Bottles_Sold'].mean()
stdev = invoices_all['Bottles_Sold'].std()
invoices_all[invoices_all['Bottles_Sold'] > avg+4*stdev]

# %% [markdown]
# You should plot and observe if there are any clusters as well and what those may imply for the business perspective.
#
# Similarly, you should consider the review ratings and any correlations with particular products, product categories, or other features.

# %% [markdown]
# **Report on your findings:  any statistically significant correlations in ratings, in sales, etc., as well as any outliers in the data which seem suspicious to you and why.**  I don't presuppose anything about what may or may not be in these data.  If no one on your team knows much about statistics, then rely more on expanding the basic analyses I've sketched above.

# %% [markdown]
# ## A Recommendation Engine

# %% [markdown]
# Your business manager has suggested using the review ratings as a resource for a recommendation engine.  A recommendation engine takes a product and searches for things those who rated this product highly also liked.
#
# A colleague of yours produced a recommendation engine using the principles outlined in the Data Analytics section of this program.  **You should prepare the data to plug into the recommendation engine, run some examples, and produce a report on the behavior and suitability.**

# %% [markdown]
# ### `holden`

# %% [markdown]
# The essence of a recommendation engine is that it take a particular exemplar and produce a short list of similar suggestions.  This may be done on one of several bases:
#
# 1. Raw popularity.  Simply return similarly-rated items.  This is coarse but trivial.
# 2. Content similarity.  Requires extensive metadata tagging.  Combines
# 3. Collaborative filtering.  Based on who rates a product highly and what else they rate highly.  (This is our approach.)
#
#     We have customer rating data tied to invoices, and invoice data tied to soft drink data, so we are able to produce a recommendation engine which operates on the appropriate columns.
#
# The recommendation engine `holden` is written in Python and accepts fields of data to compare.  These may be NumPy arrays, Pandas Series (columns from dataframes), or extracted from SQL via PySQL.
#
# I have tried to make `holden` fairly robust, but it requires a few columns:  `'Customer_id'`, `'Rating'`, `'Item_id'`, and `'Item_Description'`.

# %%
import holden

rec = holden.holden()
rec.initialize(all_df)

# %%
rec.match("Seira's Black Cherry")
